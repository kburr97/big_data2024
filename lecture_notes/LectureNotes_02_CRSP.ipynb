# %% [markdown]
# # Big Data in Finance: Part II <BR><BR> Lecture Notes 2: CRSP
#
# **Instructor** <BR>
# Kirsten Burr, kburr26@gsb.columbia.edu
#
# **TA's:** <BR>
# Meha Sadasivam, MSadasivam21@gsb.columbia.edu <BR>
# Daheng Yang, dyang22@gsb.columbia.edu
#
# <sub> Credit: lecture notes originally developed by Lira Mota

# %% [markdown]
# **Objectives:** <BR>
# 1. Download and understand the basics of CRSP tables:
#     1. Monthly Stock Files (MSF)
#     2. Monthly Stock Events (MSE)
#     2. Risk free rates (MCTI)

# %% [markdown]
# 2. Create one data frame with the following variables:
#     1. Stock exchange code
#     2. Security code
#     3. Stock monthly returns
#     4. Market Equity Value (AMT*PRC)
#     5. Risk Free Rate

# %% [markdown]
#
# 3. Add variables:
#     1. Rankyear - Fama and French yearly rebalancing schedule
#     2. Returns adjusted for delisting
#     3. ME by PERMCO
#     4. ME lag (used for portfolios weights)
#     5. Cumulative past 11 months returns (used to calculate momentum portfolios - homework 2)

# %% [markdown]
# ## Set Up

# %%
# %matplotlib inline 

# Packages 
import wrds
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 6]

import time
from time import strptime, strftime

# Setups
pd.set_option("display.max_rows", 200) # max number or rows to be displayed

# %%
# Set WRDS Connection
db = wrds.Connection(wrds_username='khardnett') # make sure to configure wrds connector before hand.
# Out:
# Loading library list...
# Done

# %% [markdown]
# ## How is the CRSP data organized?

# %%
libs = db.list_libraries()
# Transform crsp_tables to a Pandas data frame to have a better display.
libs = pd.DataFrame({'libs':libs}).sort_values('libs').reset_index(drop=True) 
libs.head(100)
# Out:
#                            libs
# 0                    aha_sample
# 1                       ahasamp
# 2                         audit
# 3                 audit_acct_os
# 4              audit_audit_comp
# 5                  audit_common
# 6              audit_corp_legal
# 7                      auditsmp
# 8                  auditsmp_all
# 9                          bank
# 10                     bank_all
# 11                        block
# 12                    block_all
# 13                      boardex
# 14                  boardex_eur
# 15                   boardex_na
# 16                  boardex_row
# 17                boardex_trial
# 18                   boardex_uk
# 19                     boardsmp
# 20                          bvd
# 21                bvd_ama_large
# 22               bvd_ama_medium
# 23                bvd_ama_small
# 24            bvd_ama_verylarge
# 25            bvd_amadeus_trial
# 26                 bvd_bvdbankf
# 27           bvd_bvdbankf_trial
# 28              bvd_orbis_large
# 29             bvd_orbis_medium
# 30              bvd_orbis_small
# 31              bvd_orbis_trial
# 32                      bvdsamp
# 33              calcbench_trial
# 34                     calcbnch
# 35                         cboe
# 36                     cboe_all
# 37                          ciq
# 38                   ciq_common
# 39                   ciq_keydev
# 40                  ciq_ratings
# 41              ciq_transcripts
# 42                      ciqsamp
# 43             ciqsamp_capstrct
# 44               ciqsamp_common
# 45               ciqsamp_keydev
# 46             ciqsamp_pplintel
# 47              ciqsamp_ratings
# 48         ciqsamp_transactions
# 49          ciqsamp_transcripts
# 50                     cisdmsmp
# 51                     columnar
# 52                         comp
# 53                    comp_bank
# 54              comp_bank_daily
# 55              comp_emdb_daily
# 56            comp_emdb_monthly
# 57               comp_execucomp
# 58                 comp_filings
# 59                  comp_global
# 60            comp_global_daily
# 61           comp_na_annual_all
# 62            comp_na_daily_all
# 63          comp_na_monthly_all
# 64           comp_segments_hist
# 65     comp_segments_hist_daily
# 66                comp_snapshot
# 67                        compa
# 68                        compb
# 69                        compg
# 70                        compm
# 71                     compsamp
# 72                 compsamp_all
# 73            compsamp_snapshot
# 74                      compseg
# 75                     compsnap
# 76                      contrib
# 77  contrib_as_filed_financials
# 78         contrib_ceo_turnover
# 79         contrib_char_returns
# 80              contrib_general
# 81        contrib_global_factor
# 82     contrib_intangible_value
# 83                 contrib_kpss
# 84                 contrib_liva
# 85                         crsp
# 86                   crsp_a_ccm
# 87               crsp_a_indexes
# 88                 crsp_a_stock
# 89            crsp_a_treasuries
# 90                   crsp_q_ccm
# 91               crsp_q_indexes
# 92             crsp_q_indexhist
# 93           crsp_q_mutualfunds
# 94                 crsp_q_stock
# 95            crsp_q_treasuries
# 96                        crspq
# 97                     crspsamp
# 98                 crspsamp_all
# 99                  crspsamp_mf

# %%
libs.shape
# Out:
# (368, 1)

# %% [markdown]
# ### All tables in CRSPQ

# %%
# crspq: CRSP quartely update
crsp_tables = db.list_tables(library="crsp") 
# crspm: CRSP monthly update - not included in our subscription

# Transform crsp_tables to a Pandas data frame to have a better display.
crsp_tables = pd.DataFrame({'tables':crsp_tables}).sort_values('tables').reset_index(drop=True)  
crsp_tables.head(150)
# Out:
#                        tables
# 0                        acti
# 1                        asia
# 2                        asib
# 3                        asic
# 4                        asio
# 5                        asix
# 6                      bmdebt
# 7                    bmheader
# 8                    bmpaymts
# 9                    bmquotes
# 10                    bmyield
# 11                   bndprt06
# 12                   bndprt12
# 13                   bxcalind
# 14                   bxdlyind
# 15                   bxmthind
# 16                   bxquotes
# 17                    bxyield
# 18                        cap
# 19                 ccm_lookup
# 20                 ccm_qvards
# 21           ccmxpf_linktable
# 22             ccmxpf_lnkhist
# 23              ccmxpf_lnkrng
# 24             ccmxpf_lnkused
# 25                   comphead
# 26                   comphist
# 27                 compmaster
# 28               contact_info
# 29               crsp_cik_map
# 30            crsp_daily_data
# 31                crsp_header
# 32          crsp_monthly_data
# 33                 crsp_names
# 34            crsp_portno_map
# 35     crsp_ziman_daily_index
# 36   crsp_ziman_monthly_index
# 37                     cs20yr
# 38                      cs5yr
# 39                      cs90d
# 40                   cst_hist
# 41                  daily_nav
# 42              daily_nav_ret
# 43              daily_returns
# 44                  dividends
# 45                     dport1
# 46                     dport2
# 47                     dport3
# 48                     dport4
# 49                     dport5
# 50                     dport6
# 51                     dport7
# 52                     dport8
# 53                     dport9
# 54                       dsbc
# 55                       dsbo
# 56                        dse
# 57                      dse62
# 58                dse62delist
# 59                  dse62dist
# 60             dse62exchdates
# 61                 dse62names
# 62                dse62nasdin
# 63                dse62shares
# 64                     dseall
# 65                   dseall62
# 66                  dsedelist
# 67                    dsedist
# 68               dseexchdates
# 69                   dsenames
# 70                  dsenasdin
# 71                  dseshares
# 72                        dsf
# 73                      dsf62
# 74                   dsf62_v2
# 75                     dsf_v2
# 76                     dsfhdr
# 77                   dsfhdr62
# 78                        dsi
# 79                      dsi62
# 80                       dsia
# 81                       dsib
# 82                       dsic
# 83                       dsio
# 84                       dsir
# 85                       dsix
# 86                       dsiy
# 87                     dsp500
# 88                  dsp500_v2
# 89                 dsp500list
# 90              dsp500list_v2
# 91                    dsp500p
# 92                       dssc
# 93                       dsso
# 94                    eod_cap
# 95                 eod_sector
# 96                     eod_vg
# 97                   erdport1
# 98                   erdport2
# 99                   erdport3
# 100                  erdport4
# 101                  erdport5
# 102                  erdport6
# 103                  erdport7
# 104                  erdport8
# 105                  erdport9
# 106                  ermport1
# 107                  ermport2
# 108                  ermport3
# 109                  ermport4
# 110                  ermport5
# 111                     fbpri
# 112                     fbyld
# 113                front_load
# 114            front_load_det
# 115            front_load_grp
# 116                 fund_fees
# 117                fund_flows
# 118                  fund_hdr
# 119             fund_hdr_hist
# 120                fund_names
# 121                fund_style
# 122              fund_summary
# 123             fund_summary2
# 124                  fwdask06
# 125                  fwdask12
# 126                  fwdave06
# 127                  fwdave12
# 128                  fwdbid06
# 129                  fwdbid12
# 130                  hldask06
# 131                  hldask12
# 132                  hldave06
# 133                  hldave12
# 134                  hldbid06
# 135                  hldbid12
# 136                  holdings
# 137          holdings_co_info
# 138     idx_const_close_pf_v2
# 139        idx_const_close_v2
# 140      idx_const_open_pf_v2
# 141    idx_const_open_proj_v2
# 142         idx_const_open_v2
# 143                idx_levels
# 144          inddlyseriesdata
# 145        inddlyseriesdata62
# 146      inddlyseriesdata_ind
# 147        index_descriptions
# 148            index_type_map
# 149          indfamilyinfohdr

# %%
crsp_tables.shape
# Out:
# (425, 1)

# %% [markdown]
# We are going to focus on three tables:
#
# 1. MSF: Monthly Stock Files
# 2. MSE: Monthly Stock Events
# 3. MCTI: US Treasury and Inflation - Monthly
#
# Nice overview can be found [here](https://wrds-www.wharton.upenn.edu/pages/support/manuals-and-overviews/crsp/stocks-and-indices/overview-crsp-us-stock-database/).

# %% [markdown]
# ### Primary Keys (PK)
#
# * Company identifier: PERMCO
# * Security identifier: PERMNO
# * Date: monthly or daily

# %% [markdown]
# ## The Stock/Securities Files Table (msf or dsf)

# %% [markdown]
# ### All Variables in MSF

# %%
db.describe_table(library="crsp", table="msf")
# Out:
# Approximately 5037353 rows in crsp.msf.
#         name  nullable              type comment
# 0      cusip      True        VARCHAR(8)    None
# 1     permno      True           INTEGER    None
# 2     permco      True           INTEGER    None
# 3     issuno      True           INTEGER    None
# 4      hexcd      True          SMALLINT    None
# 5     hsiccd      True           INTEGER    None
# 6       date      True              DATE    None
# 7      bidlo      True    NUMERIC(11, 5)    None
# 8      askhi      True    NUMERIC(11, 5)    None
# 9        prc      True    NUMERIC(11, 5)    None
# 10       vol      True    NUMERIC(10, 0)    None
# 11       ret      True    NUMERIC(10, 6)    None
# 12       bid      True    NUMERIC(11, 5)    None
# 13       ask      True    NUMERIC(11, 5)    None
# 14    shrout      True  DOUBLE_PRECISION    None
# 15    cfacpr      True  DOUBLE_PRECISION    None
# 16   cfacshr      True  DOUBLE_PRECISION    None
# 17    altprc      True    NUMERIC(11, 5)    None
# 18    spread      True    NUMERIC(10, 5)    None
# 19  altprcdt      True              DATE    None
# 20      retx      True    NUMERIC(10, 6)    None

# %% [markdown]
# ### Extra Identifiers: names table

# %%
db.describe_table(library="crsp", table="stocknames")
# Out:
# Approximately 80790 rows in crsp.stocknames.
#          name  nullable              type comment
# 0      permno      True           INTEGER    None
# 1      namedt      True              DATE    None
# 2   nameenddt      True              DATE    None
# 3       shrcd      True          SMALLINT    None
# 4      exchcd      True          SMALLINT    None
# 5       siccd      True           INTEGER    None
# 6      ncusip      True        VARCHAR(8)    None
# 7      ticker      True        VARCHAR(8)    None
# 8      comnam      True       VARCHAR(35)    None
# 9      shrcls      True        VARCHAR(4)    None
# 10     permco      True           INTEGER    None
# 11      hexcd      True          SMALLINT    None
# 12      cusip      True        VARCHAR(8)    None
# 13    st_date      True              DATE    None
# 14   end_date      True              DATE    None
# 15    namedum      True  DOUBLE_PRECISION    None

# %% [markdown]
# ### Which firm identifier to use?
#
# * PERMCO?
# * PERMNO?
# * CUSIP?
# * NCUSIP?
# * TICKER?

# %%
## An explample of name change
names_table = db.raw_sql('SELECT * FROM crsp.stocknames')

# %%
# Google
# names_table[names_table.permno==14542]
names_table[(names_table.ticker=='GOOG')| (names_table.ticker=='GOOGL')].sort_values('namedt')
# Out:
#        permno      namedt   nameenddt  shrcd  exchcd  siccd    ncusip ticker  \
# 74136   90319  2004-08-19  2014-04-02     11       3   7375  38259P50   GOOG
# 9575    14542  2014-04-03  2015-10-04     11       3   7375  38259P70   GOOG
# 74137   90319  2014-04-03  2015-10-04     11       3   7375  38259P50  GOOGL
# 9576    14542  2015-10-05  2023-12-29     11       3   7375  02079K10   GOOG
# 74138   90319  2015-10-05  2023-12-29     11       3   7375  02079K30  GOOGL
#
#              comnam shrcls  permco  hexcd     cusip     st_date    end_date  \
# 74136    GOOGLE INC      A   45483      3  02079K30  2004-08-19  2023-12-29
# 9575     GOOGLE INC      C   45483      3  02079K10  2014-04-03  2023-12-29
# 74137    GOOGLE INC      A   45483      3  02079K30  2004-08-19  2023-12-29
# 9576   ALPHABET INC      C   45483      3  02079K10  2014-04-03  2023-12-29
# 74138  ALPHABET INC      A   45483      3  02079K30  2004-08-19  2023-12-29
#
#        namedum
# 74136      2.0
# 9575       2.0
# 74137      2.0
# 9576       2.0
# 74138      2.0

# %%
# HP
names_table[names_table.permno==32707]
# Out:
#        permno      namedt   nameenddt  shrcd  exchcd  siccd    ncusip ticker  \
# 28883   32707  1962-07-02  1963-03-19     11       2   1311      None     HP
# 28884   32707  1963-03-20  1968-01-01     11       1   1311      None     HP
# 28885   32707  1968-01-02  2011-06-09     11       1   1311  42345210     HP
# 28886   32707  2011-06-10  2023-12-29     11       1   1381  42345210     HP
#
#                       comnam shrcls  permco  hexcd     cusip     st_date  \
# 28883  HELMERICH & PAYNE INC   None   20902      1  42345210  1962-07-02
# 28884  HELMERICH & PAYNE INC   None   20902      1  42345210  1962-07-02
# 28885  HELMERICH & PAYNE INC   None   20902      1  42345210  1962-07-02
# 28886  HELMERICH & PAYNE INC   None   20902      1  42345210  1962-07-02
#
#          end_date  namedum
# 28883  2023-12-29      2.0
# 28884  2023-12-29      2.0
# 28885  2023-12-29      2.0
# 28886  2023-12-29      2.0

# %%
# One permco, multiple permno, multiple cusip

# AT&T
names_table[names_table.permco==20103]
# Out:
#        permno      namedt   nameenddt  shrcd  exchcd  siccd    ncusip ticker  \
# 1039    10401  1925-12-31  1962-07-01     11       1   4810      None   None
# 1040    10401  1962-07-02  1968-01-01     11       1   4811      None      T
# 1041    10401  1968-01-02  1994-04-20     11       1   4811  03017710      T
# 1042    10401  1994-04-21  2001-02-28     11       1   4812  00195710      T
# 1043    10401  2001-03-01  2002-11-18     11       1   4813  00195710      T
# 1044    10401  2002-11-19  2005-11-18     11       1   4813  00195750      T
# 67652   86746  1999-03-10  2001-02-28     11       1   4812  00195720    LMG
# 67653   86746  2001-03-01  2001-08-09     11       1   4813  00195720    LMG
# 67654   86747  1999-03-10  2001-02-28     11       1   4812  00195730    LMG
# 67655   86747  2001-03-01  2001-08-09     11       1   4813  00195730    LMG
# 69712   87831  2000-04-27  2001-02-28     11       1   4812  00195740    AWE
# 69713   87831  2001-03-01  2001-07-06     11       1   4813  00195740    AWE
#
#                               comnam shrcls  permco  hexcd     cusip  \
# 1039   AMERICAN TELEPHONE & TELEG CO   None   20103      1  00195750
# 1040   AMERICAN TELEPHONE & TELEG CO   None   20103      1  00195750
# 1041   AMERICAN TELEPHONE & TELEG CO   None   20103      1  00195750
# 1042                    A T & T CORP   None   20103      1  00195750
# 1043                    A T & T CORP   None   20103      1  00195750
# 1044                    A T & T CORP   None   20103      1  00195750
# 67652                   A T & T CORP      A   20103      1  00195720
# 67653                   A T & T CORP      A   20103      1  00195720
# 67654                   A T & T CORP      B   20103      1  00195730
# 67655                   A T & T CORP      B   20103      1  00195730
# 69712                   A T & T CORP   None   20103      1  00195740
# 69713                   A T & T CORP   None   20103      1  00195740
#
#           st_date    end_date  namedum
# 1039   1925-12-31  2005-11-18      2.0
# 1040   1925-12-31  2005-11-18      2.0
# 1041   1925-12-31  2005-11-18      2.0
# 1042   1925-12-31  2005-11-18      2.0
# 1043   1925-12-31  2005-11-18      2.0
# 1044   1925-12-31  2005-11-18      2.0
# 67652  1999-03-10  2001-08-09      2.0
# 67653  1999-03-10  2001-08-09      2.0
# 67654  1999-03-10  2001-08-09      2.0
# 67655  1999-03-10  2001-08-09      2.0
# 69712  2000-04-27  2001-07-06      2.0
# 69713  2000-04-27  2001-07-06      2.0

# %% [markdown]
# ### Difference between header information and historical information
#
# * Usually "h" in CRSP means header - a static characteristic. Either the most recent observation (hsiccd) or as the time the security was listed (hexcd).
# * Historical data: siccd, excd, etc.
# * Notice that for CUSIP it is different. Historical cusip is under NCUSIP.

# %% [markdown]
# ### Variables of interest
#
# 1. Identifiers: date, permno, permco
# 2. Price: prc
# 3. Return: ret
# 4. Return Ex-dividend: retx
# 5. Factor to adjust prices and shares outstading: 'cfacpr'/'cfacshr'
#
#
# Where to find variable definitions? [WRDS website](https://wrds-www.wharton.upenn.edu/documents/396/CRSP_US_Stock_Indices_Data_Descriptions.pdf).

# %%
sfvars = ['prc','vol','ret', 'retx','cfacpr','cfacshr']
query = """SELECT date, permno, permco, {} 
           FROM crsp.msf
           WHERE date>='1980-01-01'""".format(', '.join(sfvars))
print(query)
# Out:
# SELECT date, permno, permco, prc, vol, ret, retx, cfacpr, cfacshr
#            FROM crsp.msf
#            WHERE date>='1980-01-01'

# %%
msf_data = db.raw_sql(query, date_cols=['date'])
del(sfvars, query)

# %% [markdown]
# **Look at the data**

# %%
msf_data.head()
# Out:
#         date  permno  permco     prc     vol       ret      retx  cfacpr  \
# 0 1985-12-31   10000    7952     NaN     NaN       NaN       NaN     NaN
# 1 1986-01-31   10000    7952 -4.3750  1771.0       NaN       NaN     1.0
# 2 1986-02-28   10000    7952 -3.2500   828.0 -0.257143 -0.257143     1.0
# 3 1986-03-31   10000    7952 -4.4375  1078.0  0.365385  0.365385     1.0
# 4 1986-04-30   10000    7952 -4.0000   957.0 -0.098592 -0.098592     1.0
#
#    cfacshr
# 0      NaN
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0

# %%
# Check if we have a primary key
msf_data.duplicated(subset=['permno', 'date']).sum()
# Out:
# 0

# %%
msf_data.groupby(['permco', 'date']).permno.nunique().mean()
# Out:
# 1.1024615235420048

# %%
msf_data.groupby(['permco', 'date']).permno.nunique().max()
# Out:
# 320

# %%
# Cumulative returns of Apple 
apple_ret = msf_data[msf_data.permno==14593].set_index(['date']).ret
((1+apple_ret).cumprod()).plot(title='Cumulative Returns of Apple')
# Out:
# <Axes: title={'center': 'Cumulative Returns of Apple'}, xlabel='date'>

# %%
# Cumulative returns of Apple 
apple_ret = msf_data[msf_data.permno==14593].set_index(['date']).ret
((1+apple_ret).cumprod()).plot(title='Cumulative Returns of Apple', logy=True)
# Out:
# <Axes: title={'center': 'Cumulative Returns of Apple'}, xlabel='date'>

# %% [markdown]
# ## The Stock/Security Events (mse, mseall, dse, dseall)

# %% [markdown]
# ### All variables in MSEALL

# %%
# Loot at columns you could download 
db.describe_table(library="crsp", table="mseall")
# Out:
# Approximately 3635797 rows in crsp.mseall.
#         name  nullable              type comment
# 0       date      True              DATE    None
# 1     comnam      True       VARCHAR(32)    None
# 2      cusip      True        VARCHAR(8)    None
# 3     dclrdt      True              DATE    None
# 4      dlamt      True    NUMERIC(11, 5)    None
# 5      dlpdt      True              DATE    None
# 6     dlstcd      True          SMALLINT    None
# 7     hsiccd      True           INTEGER    None
# 8     issuno      True           INTEGER    None
# 9     ncusip      True        VARCHAR(8)    None
# 10    nextdt      True              DATE    None
# 11     paydt      True              DATE    None
# 12    rcrddt      True              DATE    None
# 13    shrcls      True        VARCHAR(1)    None
# 14    shrflg      True          SMALLINT    None
# 15    ticker      True        VARCHAR(5)    None
# 16    permno      True           INTEGER    None
# 17    permco      True           INTEGER    None
# 18     hexcd      True          SMALLINT    None
# 19    hsicmg      True  DOUBLE_PRECISION    None
# 20    hsicig      True  DOUBLE_PRECISION    None
# 21  nameendt      True              DATE    None
# 22     shrcd      True          SMALLINT    None
# 23    exchcd      True          SMALLINT    None
# 24     siccd      True           INTEGER    None
# 25   tsymbol      True       VARCHAR(10)    None
# 26     naics      True        VARCHAR(7)    None
# 27  primexch      True        VARCHAR(1)    None
# 28   trdstat      True        VARCHAR(1)    None
# 29   secstat      True        VARCHAR(1)    None
# 30    distcd      True          SMALLINT    None
# 31    divamt      True    NUMERIC(11, 5)    None
# 32     facpr      True    NUMERIC(10, 5)    None
# 33    facshr      True    NUMERIC(10, 5)    None
# 34    acperm      True           INTEGER    None
# 35    accomp      True           INTEGER    None
# 36    shrout      True    NUMERIC(10, 0)    None
# 37  shrenddt      True              DATE    None
# 38    nwperm      True           INTEGER    None
# 39    nwcomp      True           INTEGER    None
# 40    dlretx      True    NUMERIC(10, 6)    None
# 41     dlprc      True    NUMERIC(11, 5)    None
# 42     dlret      True    NUMERIC(10, 6)    None
# 43    trtscd      True          SMALLINT    None
# 44  trtsendt      True              DATE    None
# 45    nmsind      True          SMALLINT    None
# 46     mmcnt      True          SMALLINT    None
# 47    nsdinx      True          SMALLINT    None
# 48      year      True  DOUBLE_PRECISION    None
# 49     month      True  DOUBLE_PRECISION    None

# %% [markdown]
# ### Variables of Interest
# 1. Delisting returns: dlret, dlretx
# 2. Exchange codes: exchcd - 1 (NYSE), 2 (NYSE MKT), 3 (NASDAQ), 4 (Arca) or 5 (Bats).
# 3. Share Type Code: shrcd (usually we only look at Ordinary Common Shares, 10 and 11)
# 4. Industry classifications: siccd, naics
# 5. Stock Ticker

# %%
msevars = ['distcd','dlret', 'dlretx', 'exchcd','naics', 'ncusip', 'shrcd', 'shrout', 
           'siccd','comnam','ticker']
query = """SELECT date, permno, permco, {} 
           FROM crsp.mseall
           WHERE date>='1980-01-01'""".format(', '.join(msevars))
print(query)
# Out:
# SELECT date, permno, permco, distcd, dlret, dlretx, exchcd, naics, ncusip, shrcd, shrout, siccd, comnam, ticker
#            FROM crsp.mseall
#            WHERE date>='1980-01-01'

# %%
mse_data = db.raw_sql(query, date_cols=['date'])
del(msevars, query)

# %% [markdown]
# **Look at the data...**

# %%
mse_data[mse_data.permno==14593]
# Out:
#              date  permno  permco  distcd  dlret  dlretx  exchcd   naics  \
# 394456 1980-12-31   14593       7     NaN    NaN     NaN     3.0    None
# 394457 1981-06-30   14593       7     NaN    NaN     NaN     3.0    None
# 394458 1981-09-30   14593       7     NaN    NaN     NaN     3.0    None
# 394459 1981-12-31   14593       7     NaN    NaN     NaN     3.0    None
# 394460 1982-03-31   14593       7     NaN    NaN     NaN     3.0    None
# ...           ...     ...     ...     ...    ...     ...     ...     ...
# 394950 2023-08-31   14593       7  1232.0    NaN     NaN     3.0  334220
# 394951 2023-09-29   14593       7     NaN    NaN     NaN     3.0  334220
# 394952 2023-10-31   14593       7     NaN    NaN     NaN     3.0  334220
# 394953 2023-11-30   14593       7  1232.0    NaN     NaN     3.0  334220
# 394954 2023-12-29   14593       7     NaN    NaN     NaN     3.0  334220
#
#           ncusip  shrcd      shrout   siccd              comnam ticker
# 394456  03783310   11.0     55136.0  3573.0  APPLE COMPUTER INC   AAPL
# 394457  03783310   11.0     55136.0  3573.0  APPLE COMPUTER INC   AAPL
# 394458  03783310   11.0     55309.0  3573.0  APPLE COMPUTER INC   AAPL
# 394459  03783310   11.0     55421.0  3573.0  APPLE COMPUTER INC   AAPL
# 394460  03783310   11.0     56488.0  3573.0  APPLE COMPUTER INC   AAPL
# ...          ...    ...         ...     ...                 ...    ...
# 394950  03783310   11.0  15634232.0  3571.0           APPLE INC   AAPL
# 394951  03783310   11.0  15550061.0  3571.0           APPLE INC   AAPL
# 394952  03783310   11.0  15552752.0  3571.0           APPLE INC   AAPL
# 394953  03783310   11.0  15552752.0  3571.0           APPLE INC   AAPL
# 394954  03783310   11.0  15552752.0  3571.0           APPLE INC   AAPL
#
# [499 rows x 14 columns]

# %% [markdown]
# ### Check Primary Key

# %%
# Check PK
mse_data.duplicated(subset=['date','permno']).sum()
# Out:
# 36518

# %%
# Check Duplicates
mse_data[mse_data.duplicated(subset=['date','permno'])]
# Out:
#              date  permno  permco  distcd  dlret  dlretx  exchcd   naics  \
# 59     1994-06-30   10001    7953  5523.0    NaN     NaN     3.0    None
# 197    2008-02-29   10001    7953  1222.0    NaN     NaN     3.0  221210
# 351    1993-12-31   10002    7954  1272.0    NaN     NaN     3.0    None
# 1811   1986-12-31   10020    7972  1212.0    NaN     NaN     3.0    None
# 1830   1988-12-30   10020    7972  1232.0    NaN     NaN     3.0    None
# ...           ...     ...     ...     ...    ...     ...     ...     ...
# 288891 2010-12-31   93413   51187  1272.0    NaN     NaN     4.0  525990
# 288892 2010-12-31   93413   51187  2216.0    NaN     NaN     4.0  525990
# 289325 2010-12-31   93417   53120  2216.0    NaN     NaN     4.0  525990
# 289899 2020-12-31   93421   52902  2216.0    NaN     NaN     4.0  525990
# 289912 2021-12-31   93421   52902  2216.0    NaN     NaN     4.0  525990
#
#           ncusip  shrcd   shrout   siccd                            comnam  \
# 59      29274A10   11.0   2191.0  4920.0                   ENERGY WEST INC
# 197     29274A20   11.0   4345.0  4920.0                   ENERGY WEST INC
# 351     83623410   11.0   2999.0  6710.0  SOUTH ALABAMA BANCORPORATION INC
# 1811    49307510   11.0   5800.0  6710.0          KEY CENTURION BANCSHARES
# 1830    49307510   11.0  20281.0  6710.0          KEY CENTURION BANCSHARES
# ...          ...    ...      ...     ...                               ...
# 288891  18383M88   73.0   1100.0  6726.0              CLAYMORE E T F TRUST
# 288892  18383M88   73.0   1100.0  6726.0              CLAYMORE E T F TRUST
# 289325  37950E78   73.0   1800.0  6726.0                    GLOBAL X FUNDS
# 289899  46138E63   73.0   4450.0  6726.0            INVESCO E T F TRUST II
# 289912  46138E63   73.0   5650.0  6726.0            INVESCO E T F TRUST II
#
#        ticker
# 59       EWST
# 197      EWST
# 351      SABC
# 1811     KEYC
# 1830     KEYC
# ...       ...
# 288891   BSCB
# 288892   BSCB
# 289325   BRAZ
# 289899   PICB
# 289912   PICB
#
# [36518 rows x 14 columns]

# %%
mse_data[(mse_data.permno==10001)&(mse_data.date=='2008-02-29')]
# Out:
#           date  permno  permco  distcd  dlret  dlretx  exchcd   naics  \
# 196 2008-02-29   10001    7953  5523.0    NaN     NaN     3.0  221210
# 80784    ITML
# 93934    PACQ
# 144610    SNL
# 150528    ROK
# 171756    RXM
# 236589    FZT
# 242588    IPL
# 313779    BAT
# 313780    BAT
# 313781    BAT
# 313782    BAT
# 313783    BAT
# 313784    BAT
# 313787    BAT
# 343210    ENS
# 361667    SKB
# 361668    SKB
# 361670    SKB
# 364281    TEN
# 371505     BV
# 372278    AHS
# 436923    PCI
# 436924    PCI
# 436925    PCI
# 466924   FIAM
# 3427      WCI
# 27187     PRE
# 96748     AXE
# 126640    BEV
# 132721    GGG
# 138721     FR
# 138722     FR
# 138723     FR
# 138724     FR
# 144942   LIBH
# 159322    HLD
# 159323    HLD
# 159324    HLD
# 186696    COO
# 186697    COO
# 288312   OCEY
# 314002    SFM
# 318688   PANX
# 354681   PMAN
# 358759    HZR
# 367428    UCT
# 390365   QNTM
# 400414    CDL
# 422867    AFC
# 454582    HHH
# 6056      CAA
# 14683    SRFI
# 71391     VMT
# 71392     VMT
# 89197    GSCX
# 134608   HENG
# 134609   HENG
# 147989    SXC
# 157023    SWY
# 190264    NQN
# 196665    HMA
# 199651   TKCR
# 207342    NVN
# 212454   CHKE
# 212455   CHKE
# 228108    BMN
# 256948   BGII
# 261002    NUN
# 261999    VPQ
# 262354    VFM
# 262535    VNM
# 264682    NIF
# 283230    BMT
# 292047   AMVC
# 303119     EP
# 312467    VMN
# 316328    VTF
# 360700    VAP
# 363222    NIR
# 391979   UACI
# 414378    NNF
# 443530    NCL
# 453273   BPYU
# 473187   USTC
# 482410    VNV
# 492217    NPX
# 275       RET
# 14118      SD
# 27321     VYM
# 28272     CPG
# 61866     FLC
# 61867     FLC
# 164222  AGRPA
# 164274  AGRPB
# 213269   DLBI
# 213272   DLBI
# 233678    UMG
# 244962   CFLO
# 274664   WILL
# 334721     CP
# 334722     CP
# 334723     CP
# 334724     CP
# 336559   ACRI
# 353768   ALGO
# 374400    PDS
# 417057    CWZ
# 426614   GFLS
# 447259    ELP
# 80917     FEV
# 109008   RBAK
# 212050    RKH
# 212051    RKH
# 212052    RKH
# 213138    UTH
# 213139    UTH
# 213140    UTH
# 213141    UTH
# 233029    MKH
# 233030    MKH
# 233031    MKH
# 233032    MKH
# 233033    MKH
# 233034    MKH
# 233035    MKH
# 233036    MKH
# 233037    MKH
# 233038    MKH
# 233039    MKH
# 233040    MKH
# 258822    TEM
# 259187    WMH
# 259188    WMH
# 259189    WMH
# 266570  COMMA
# 268553    OIH
# 280169    RTH
# 280171    RTH
# 280172    RTH
# 294402      L
# 294462    LMC
# 296498    HCH
# 300213    BPK
# 300427    BLH
# 300640    BJZ
# 319914    NKO
# 327364    AAA
# 339264    TTH
# 339265    TTH
# 339266    TTH
# 339268    TTH
# 353997    TFT
# 353998    TFT
# 358393  PENRF
# 362688   VMED
# 425286    LCC
# 483476   XGEN
# 453       FHI
# 128711    FHO
# 179188    INY
# 179312    CXA
# 181065   ABII
# 183448    NMD
# 287311   BABS

# %% [markdown]
# ### DISTCD causes duplicates
# * DISTCD: event code that records list of events describing cash dividends, capital adjustments, and other distributions made to shareholders of a security;
# * For stock/date there might be multiple events.
# * For example, in the case of Energy West (EWST)
#     * 1222: US cash dividend, monthly, taxable same rate as dividends
#     * 5523: Stock split, non-taxable

# %%
# Redownlod without distcd 
msevars = ['comnam', 'dlret', 'dlretx', 'exchcd','naics', 'cusip', 'ncusip', 'shrcd', 'shrout', 
           'siccd','ticker']
query = """SELECT date, permno, permco, {} 
           FROM crspq.mseall
           WHERE date>='1980-01-01'""".format(', '.join(msevars))
print(query)
# Out:
# SELECT date, permno, permco, comnam, dlret, dlretx, exchcd, naics, cusip, ncusip, shrcd, shrout, siccd, ticker
#            FROM crspq.mseall
#            WHERE date>='1980-01-01'

# %%
mse_data = db.raw_sql(query, date_cols=['date'])
del(msevars, query)

# %%
mse_data = mse_data[~mse_data.duplicated()].copy()

# %%
# Check PK
mse_data.duplicated(subset=['date','permno']).sum()
# Out:
# 0

# %%
mse_data.head()
# Out:
#         date  permno  permco                     comnam  dlret  dlretx  \
# 0 1986-01-31   10000    7952  OPTIMUM MANUFACTURING INC    NaN     NaN
# 1 1986-03-31   10000    7952  OPTIMUM MANUFACTURING INC    NaN     NaN
# 2 1986-04-30   10000    7952  OPTIMUM MANUFACTURING INC    NaN     NaN
# 3 1986-05-30   10000    7952  OPTIMUM MANUFACTURING INC    NaN     NaN
# 4 1986-06-30   10000    7952  OPTIMUM MANUFACTURING INC    NaN     NaN
#
#    exchcd naics     cusip    ncusip  shrcd  shrout   siccd ticker
# 0     3.0  None  68391610  68391610   10.0  3680.0  3990.0  OMFGA
# 1     3.0  None  68391610  68391610   10.0  3680.0  3990.0  OMFGA
# 2     3.0  None  68391610  68391610   10.0  3793.0  3990.0  OMFGA
# 3     3.0  None  68391610  68391610   10.0  3793.0  3990.0  OMFGA
# 4     3.0  None  68391610  68391610   10.0  3793.0  3990.0  OMFGA

# %% [markdown]
# ## Merge MSF and MSEALL

# %% [markdown]
# When merging mse and msf tables we should copy information from event observations to succeeding non-event observations.

# %% [markdown]
# Check data types: for some reason the merge does not work for PERMNO as float

# %%
msf_data.dtypes
# Out:
# date       datetime64[ns]
# permno              int64
# permco              int64
# prc               float64
# vol               float64
# ret               float64
# retx              float64
# cfacpr            float64
# cfacshr           float64
# dtype: object

# %%
## Check data types
mse_data.dtypes
# Out:
# date      datetime64[ns]
# permno             int64
# permco             int64
# comnam            object
# dlret            float64
# dlretx           float64
# exchcd           float64
# naics             object
# cusip             object
# ncusip            object
# shrcd            float64
# shrout           float64
# siccd            float64
# ticker            object
# dtype: object

# %%
# Change Permno Data Type.
msf_data['permno'] = msf_data['permno'].astype('int')
mse_data['permno'] = mse_data['permno'].astype('int')

# %%
msf_data.sort_values(['date', 'permno'], inplace=True)
mse_data.sort_values(['date', 'permno'], inplace=True)

# %% [markdown]
# **Merge tables with following logic:**
# * For each msf observation, merge most recent mseall observation with same permno,
# * If particular permno-date combination does not exist in msf but does in mseall, do not include that observation.
#
# **How to do this?** Pandas is powerful!

# %%
from IPython.display import IFrame
IFrame('https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge_asof.html', width=900, height=400)
# Out:
#         <iframe
#             width="900"
#             height="400"
#             src="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge_asof.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Check of coverage
x = pd.Series(msf_data.permno.unique())
y = pd.Series(mse_data.permno.unique())

# %%
# Have price but no event?
x[~x.isin(y)][:20]
# Out:
# Series([], dtype: int64)

# %%
# Have event but no price?
y[~y.isin(x)][:20]
# Out:
# 306     30921
# 315     31544
# 359     34893
# 770     55723
# 1006    68778
# 1021    71432
# 1930    50391
# 2868    40344
# 3111    51844
# 3578    31820
# 3618    43756
# 3640    48362
# 3654    51319
# 3796    30251
# 4421    33435
# 4512    14860
# 4565    33996
# 4566    34797
# 4676    69834
# 4756    45196
# dtype: int64

# %%
# Check if delisting happens only once per security
mse_data[mse_data.dlret.notnull()].groupby(['permno']).date.value_counts().max()
# Out:
# 1

# %%
# Check if delisting returns only appears after the firm is not longer covered by msf
test = mse_data[mse_data.dlret.notnull()]
test = pd.merge(msf_data, test[['permno', 'dlret', 'date']], on=['permno'])
test[test.date_x>test.date_y]
# Out:
# Empty DataFrame
# Columns: [date_x, permno, permco, prc, vol, ret, retx, cfacpr, cfacshr, dlret, date_y]
# Index: []

# %%
crsp = pd.merge_asof(msf_data, 
                     mse_data, 
                     on='date', 
                     by=['permno','permco'], 
                     direction='backward')

# %%
crsp.columns
# Out:
# Index(['date', 'permno', 'permco', 'prc', 'vol', 'ret', 'retx', 'cfacpr',
#        'cfacshr', 'comnam', 'dlret', 'dlretx', 'exchcd', 'naics', 'cusip',
#        'ncusip', 'shrcd', 'shrout', 'siccd', 'ticker'],
#       dtype='object')

# %%
crsp[crsp.ticker=='GOOG'].head()
# Out:
#               date  permno  permco        prc        vol       ret      retx  \
# 2171823 2004-08-31   90319   45483  102.37000   669547.0       NaN       NaN
# 2178734 2004-09-30   90319   45483  129.60001  1066083.0  0.265996  0.265996
# 2185668 2004-10-29   90319   45483  190.64000  2580994.0  0.470988  0.470988
# 2192604 2004-11-30   90319   45483  181.98000  2788008.0 -0.045426 -0.045426
# 2199551 2004-12-31   90319   45483  192.78999  1457027.0  0.059402  0.059402
#
#          cfacpr  cfacshr      comnam  dlret  dlretx  exchcd   naics     cusip  \
# 2171823  39.938     20.0  GOOGLE INC    NaN     NaN     3.0  514191  02079K30
# 2178734  39.938     20.0  GOOGLE INC    NaN     NaN     3.0  514191  02079K30
# 2185668  39.938     20.0  GOOGLE INC    NaN     NaN     3.0  514191  02079K30
# 2192604  39.938     20.0  GOOGLE INC    NaN     NaN     3.0  514191  02079K30
# 2199551  39.938     20.0  GOOGLE INC    NaN     NaN     3.0  514191  02079K30
#
#            ncusip  shrcd   shrout   siccd ticker
# 2171823  38259P50   11.0  33603.0  7375.0   GOOG
# 2178734  38259P50   11.0  57857.0  7375.0   GOOG
# 2185668  38259P50   11.0  57857.0  7375.0   GOOG
# 2192604  38259P50   11.0  57857.0  7375.0   GOOG
# 2199551  38259P50   11.0  95542.0  7375.0   GOOG

# %%
# Check Primary Key
crsp.duplicated(subset=['permno','date']).sum()
# Out:
# 0

# %%
# Check Apple
crsp[crsp.permno==14593].tail()
# Out:
#               date  permno  permco        prc         vol       ret      retx  \
# 3863906 2023-08-31   14593       7  187.87000  13209699.0 -0.042454 -0.043675
# 3873426 2023-09-29   14593       7  171.21001  13366036.0 -0.088678 -0.088678
# 3882981 2023-10-31   14593       7  170.77000  11728396.0 -0.002570 -0.002570
# 3892565 2023-11-30   14593       7  189.95000  10906725.0  0.113720  0.112315
# 3902134 2023-12-29   14593       7  192.53000  10520988.0  0.013583  0.013583
#
#          cfacpr  cfacshr     comnam  dlret  dlretx  exchcd   naics     cusip  \
# 3863906     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220  03783310
# 3873426     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220  03783310
# 3882981     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220  03783310
# 3892565     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220  03783310
# 3902134     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220  03783310
#
#            ncusip  shrcd      shrout   siccd ticker
# 3863906  03783310   11.0  15634232.0  3571.0   AAPL
# 3873426  03783310   11.0  15550061.0  3571.0   AAPL
# 3882981  03783310   11.0  15552752.0  3571.0   AAPL
# 3892565  03783310   11.0  15552752.0  3571.0   AAPL
# 3902134  03783310   11.0  15552752.0  3571.0   AAPL

# %% [markdown]
# ## Calculate Variables of Interest

# %% [markdown]
# ### Adjusted Returns
#
# Add to the ret series the delisting returns

# %%
# Returns adjusted for delisting
crsp['retadj'] = ((1+crsp['ret'].fillna(0))*(1+crsp['dlret'].fillna(0))-1)
crsp.loc[crsp[['ret', 'dlret']].isnull().all(axis=1), 'retadj'] = np.nan

# %% [markdown]
# ### Market Equity Value

# %% [markdown]
# #### Can prices be negative?

# %%
(crsp.prc<0).mean()
# Out:
# 0.12838428215590655

# %%
(crsp.prc==0).mean()
# Out:
# 0.0

# %% [markdown]
# **Why Negative Prices?**<BR><BR>
#
# * If the closing price is not available for any given period, the number in the price field is replaced with a bid/ask average.
# * Bid/ask averages have dashes placed in front of them.
# * These do not incorrectly reflect negative prices; they serve to distinguish bid/ask averages from actual closing prices. If neither the price nor bid/ask average is available, the field is set to N/A.

# %% [markdown]
# #### Can number of shares outstanding be negative?

# %%
(crsp.shrout<0).sum()
# Out:
# 0

# %% [markdown]
# #### Create Market Equity (ME)

# %%
# SHROUT is the number of publicly held shares, recorded in thousands. ME will be reported in 1,000,000 ($10^6$),
# Like on Ken French's website. 
crsp['me'] = abs(crsp['prc']) * (crsp['shrout']/1000)

# %%
# Also, some companies have multiple shareclasses (=PERMNOs).
# To get the company ME, we need to calculate the sum of ME over all shareclasses for one company (=PERMCO).
# This is used for sorting, but not for weights.

# Create MEsum
crsp['mesum'] = crsp.groupby(['date', 'permco']).me.transform(np.sum, min_count=1)

# %%
# If the stock is delisted, we set ME to NaN.
crsp.loc[crsp.dlret.notnull(), 'me'] = np.nan
crsp.loc[crsp.dlret.notnull(), 'mesum'] = np.nan

# %% [markdown]
# #### Adjusting for Stock Splits and Other Corporate Actions
#
# * Returns are already adjusted for splits, but prices and shares outstanding are not.
# * To adjust prices and shares outstanding, use the following use:
#     * Adjusted prices = PRC / CFACPR
#     * Adjusted shares = SHROUT * CFACSHR

# %% [markdown]
# ### ME Lag
#
# MElag is used as portfolio weights any value weighted portfolio (eg. in the FF factors).

# %%
crsp.sort_values(['permno','date'], inplace=True)

# %%
crsp['melag_nt']=crsp.groupby(['permno']).me.shift(1)

# %%
# What to do if ME is missing?
crsp['melag'] = crsp.groupby('permno').melag_nt.fillna(method='pad')

# %% [markdown]
# ### Rankyear

# %%
# Portfolios are rebalanced in the end of june
crsp['rankyear'] = crsp.date.dt.year
crsp.loc[crsp.date.dt.month <= 6, 'rankyear'] = crsp.loc[crsp.date.dt.month <= 6, 'rankyear'] - 1

# %% [markdown]
# ## Add Risk Free

# %%
# Dowload the data
#%% Import Data
query = "SELECT caldt as date, t30ret as rf FROM crspq.mcti"
rf = db.raw_sql(query, date_cols=['date'])

# %%
rf.head()
# Out:
#         date        rf
# 0 1925-12-31       NaN
# 1 1926-01-30  0.002951
# 2 1926-02-27  0.002768
# 3 1926-03-31  0.002778
# 4 1926-04-30  0.003072

# %%
# Month dates: dates do not match directly to the ones in CRSP
rf['mdate'] = rf.date.dt.year*100+rf.date.dt.month

# %%
rf.drop(columns=['date'], inplace=True)

# %%
crsp['mdate']=crsp.date.dt.year*100+crsp.date.dt.month

# %%
crsp = pd.merge(crsp, rf, on=['mdate'])

# %%
crsp.rf.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Save Output

# %%
crsp.head()
# Out:
#         date  permno  permco  prc  vol  ret  retx  cfacpr  cfacshr comnam  \
# 0 1985-12-31   10000    7952  NaN  NaN  NaN   NaN     NaN      NaN    NaN
# 1 1985-12-31   10001    7953  NaN  NaN  NaN   NaN     NaN      NaN    NaN
# 2 1985-12-31   10002    7954  NaN  NaN  NaN   NaN     NaN      NaN    NaN
# 3 1985-12-31   10003    7957  NaN  NaN  NaN   NaN     NaN      NaN    NaN
# 4 1985-12-31   10005    7961  NaN  NaN  NaN   NaN     NaN      NaN    NaN
#
#    ...  siccd  ticker  retadj  me mesum melag_nt  melag  rankyear   mdate  \
# 0  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
# 1  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
# 2  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
# 3  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
# 4  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
#
#          rf
# 0  0.006139
# 1  0.006139
# 2  0.006139
# 3  0.006139
# 4  0.006139
#
# [5 rows x 28 columns]

# %%
crsp.columns
# Out:
# Index(['date', 'permno', 'permco', 'prc', 'vol', 'ret', 'retx', 'cfacpr',
#        'cfacshr', 'comnam', 'dlret', 'dlretx', 'exchcd', 'naics', 'cusip',
#        'ncusip', 'shrcd', 'shrout', 'siccd', 'ticker', 'retadj', 'me', 'mesum',
#        'melag_nt', 'melag', 'rankyear', 'mdate', 'rf'],
#       dtype='object')

# %%
# Make sure to change the path here for the place you want to save the data in your computer. 
crsp.to_pickle(path='./crsp_monthly.pkl')
