# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup" data-toc-modified-id="Setup-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup</a></span></li><li><span><a href="#How-is-the-CRSP-data-organized?" data-toc-modified-id="How-is-the-CRSP-data-organized?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>How is the CRSP data organized?</a></span><ul class="toc-item"><li><span><a href="#All-tables-in-CRSP" data-toc-modified-id="All-tables-in-CRSP-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>All tables in CRSP</a></span></li><li><span><a href="#Primary-Keys-(PK)" data-toc-modified-id="Primary-Keys-(PK)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Primary Keys (PK)</a></span></li></ul></li><li><span><a href="#The-Stock/Securities-Files-Table-(msf-or-dsf)" data-toc-modified-id="The-Stock/Securities-Files-Table-(msf-or-dsf)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>The Stock/Securities Files Table (msf or dsf)</a></span><ul class="toc-item"><li><span><a href="#All-Variables-in-MSF" data-toc-modified-id="All-Variables-in-MSF-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>All Variables in MSF</a></span></li><li><span><a href="#Extra-Identifiers:-names-table" data-toc-modified-id="Extra-Identifiers:-names-table-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Extra Identifiers: names table</a></span></li><li><span><a href="#Which-firm-identifier-to-use?" data-toc-modified-id="Which-firm-identifier-to-use?-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Which firm identifier to use?</a></span></li><li><span><a href="#Difference-between-header-information-and-historical-information" data-toc-modified-id="Difference-between-header-information-and-historical-information-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Difference between header information and historical information</a></span></li><li><span><a href="#Variables-of-interest" data-toc-modified-id="Variables-of-interest-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Variables of interest</a></span></li></ul></li><li><span><a href="#The-Stock/Security-Events-(mse,-mseall,-dse,-dseall)" data-toc-modified-id="The-Stock/Security-Events-(mse,-mseall,-dse,-dseall)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>The Stock/Security Events (mse, mseall, dse, dseall)</a></span><ul class="toc-item"><li><span><a href="#All-variables-in-MSEALL" data-toc-modified-id="All-variables-in-MSEALL-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>All variables in MSEALL</a></span></li><li><span><a href="#Variables-of-Interest" data-toc-modified-id="Variables-of-Interest-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Variables of Interest</a></span></li><li><span><a href="#Check-Primary-Key" data-toc-modified-id="Check-Primary-Key-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Check Primary Key</a></span></li><li><span><a href="#DISTCD-causes-duplicates" data-toc-modified-id="DISTCD-causes-duplicates-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>DISTCD causes duplicates</a></span></li></ul></li><li><span><a href="#Merge-MSF-and-MSEALL" data-toc-modified-id="Merge-MSF-and-MSEALL-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Merge MSF and MSEALL</a></span></li><li><span><a href="#Calculate-Variables-of-Interest" data-toc-modified-id="Calculate-Variables-of-Interest-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Calculate Variables of Interest</a></span><ul class="toc-item"><li><span><a href="#Adjusted-Returns" data-toc-modified-id="Adjusted-Returns-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Adjusted Returns</a></span></li><li><span><a href="#Market-Equity-Value" data-toc-modified-id="Market-Equity-Value-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Market Equity Value</a></span><ul class="toc-item"><li><span><a href="#Can-prices-be-negative?" data-toc-modified-id="Can-prices-be-negative?-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Can prices be negative?</a></span></li><li><span><a href="#Can-number-of-shares-outstanding-be-negative?" data-toc-modified-id="Can-number-of-shares-outstanding-be-negative?-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Can number of shares outstanding be negative?</a></span></li><li><span><a href="#Create-Market-Equity-(ME)" data-toc-modified-id="Create-Market-Equity-(ME)-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Create Market Equity (ME)</a></span></li><li><span><a href="#Adjusting-for-Stock-Splits-and-Other-Corporate-Actions" data-toc-modified-id="Adjusting-for-Stock-Splits-and-Other-Corporate-Actions-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>Adjusting for Stock Splits and Other Corporate Actions</a></span></li></ul></li><li><span><a href="#ME-Lag" data-toc-modified-id="ME-Lag-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>ME Lag</a></span></li><li><span><a href="#Rankyear" data-toc-modified-id="Rankyear-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Rankyear</a></span></li></ul></li><li><span><a href="#Add-Risk-Free" data-toc-modified-id="Add-Risk-Free-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Add Risk Free</a></span></li><li><span><a href="#Save-Output" data-toc-modified-id="Save-Output-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Save Output</a></span></li></ul></div>

# %% [markdown]
# # Big Data in Finance: Part IV <BR><BR> Lecture Notes 2: CRSP
#
# **Instructor** <BR>
# Kirsten Burr, kburr26@gsb.columbia.edu
#
# **TA's:** <BR>
# Meha Sadasivam, MSadasivam21@gsb.columbia.edu <BR>
# Daheng Yang, dyang22@gsb.columbia.edu
#
# <sub> Credit: lecture notes originally developed by Lira Mota

# %% [markdown]
# **Objectives:** <BR>
# 1. Download and understand the basics of CRSP tables:
#     1. Monthly Stock Files (MSF)
#     2. Monthly Stock Events (MSE)
#     2. Risk free rates (MCTI)

# %% [markdown]
# 2. Create one data frame with the following variables:
#     1. Stock exchange code
#     2. Security code
#     3. Stock monthly returns
#     4. Market Equity Value (AMT*PRC)
#     5. Risk Free Rate

# %% [markdown]
#
# 3. Add variables:
#     1. Rankyear - Fama and French yearly rebalancing schedule
#     2. Returns adjusted for delisting
#     3. ME by PERMCO
#     4. ME lag (used for portfolios weights)
#     5. Cumulative past 11 months returns (used to calculate momentum portfolios - homework)

# %% [markdown]
# ## Set Up

# %%
# %matplotlib inline 

# Packages 
import wrds
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 6]

import time
from time import strptime, strftime

# Setups
pd.set_option("display.max_rows", 200) # max number or rows to be displayed

# %%
# Set WRDS Connection
db = wrds.Connection(wrds_username='khardnett') # make sure to configure wrds connector before hand.
# Out:
# Loading library list...
# Done

# %% [markdown]
# ## How is the CRSP data organized?

# %%
libs = db.list_libraries()
# Transform crsp_tables to a Pandas data frame to have a better display.
libs = pd.DataFrame({'libs':libs}).sort_values('libs').reset_index(drop=True) 
libs.head(100)
# Out:
#                            libs
# 0                    aha_sample
# 1                       ahasamp
# 2                         audit
# 3                 audit_acct_os
# 4              audit_audit_comp
# 5                  audit_common
# 6              audit_corp_legal
# 7                      auditsmp
# 8                  auditsmp_all
# 9                         block
# 10                    block_all
# 11                      boardex
# 12                  boardex_eur
# 13                   boardex_na
# 14                  boardex_row
# 15                boardex_trial
# 16                   boardex_uk
# 17                     boardsmp
# 18                          bvd
# 19                bvd_ama_large
# 20               bvd_ama_medium
# 21                bvd_ama_small
# 22            bvd_ama_verylarge
# 23                 bvd_bvdbankf
# 24              bvd_orbis_large
# 25             bvd_orbis_medium
# 26              bvd_orbis_small
# 27              calcbench_trial
# 28                     calcbnch
# 29                         cboe
# 30                     cboe_all
# 31                          ciq
# 32                   ciq_common
# 33                   ciq_keydev
# 34                  ciq_ratings
# 35              ciq_transcripts
# 36                      ciqsamp
# 37               ciqsamp_common
# 38          ciqsamp_transcripts
# 39                     columnar
# 40                         comp
# 41                    comp_bank
# 42              comp_bank_daily
# 43              comp_emdb_daily
# 44            comp_emdb_monthly
# 45               comp_execucomp
# 46                 comp_filings
# 47                  comp_global
# 48            comp_global_daily
# 49           comp_na_annual_all
# 50            comp_na_daily_all
# 51          comp_na_monthly_all
# 52           comp_segments_hist
# 53     comp_segments_hist_daily
# 54                comp_snapshot
# 55                        compa
# 56                        compb
# 57                        compg
# 58                        compm
# 59                      compseg
# 60                     compsnap
# 61                      contrib
# 62  contrib_as_filed_financials
# 63         contrib_ceo_turnover
# 64         contrib_char_returns
# 65              contrib_general
# 66     contrib_intangible_value
# 67                 contrib_kpss
# 68                 contrib_liva
# 69                contrib_shale
# 70                         crsp
# 71                   crsp_a_ccm
# 72               crsp_a_indexes
# 73                 crsp_a_stock
# 74            crsp_a_treasuries
# 75                   crsp_q_ccm
# 76               crsp_q_indexes
# 77             crsp_q_indexhist
# 78           crsp_q_mutualfunds
# 79                 crsp_q_stock
# 80            crsp_q_treasuries
# 81                        crspq
# 82                     dealscan
# 83                       djones
# 84                   djones_all
# 85                         dmef
# 86                     dmef_all
# 87                          doe
# 88                      doe_all
# 89                         emdb
# 90                    etfg_samp
# 91                     etfgsamp
# 92           eurekahedge_sample
# 93                      eursamp
# 94                     execcomp
# 95                 factsamp_all
# 96              factsamp_revere
# 97                           ff
# 98                       ff_all
# 99                         fisd

# %%
libs.shape
# Out:
# (309, 1)

# %% [markdown]
# ### All tables in CRSPQ

# %%
# crspq: CRSP quartely update
crsp_tables = db.list_tables(library="crsp") 
# crspm: CRSP monthly update - not included in our subscription

# Transform crsp_tables to a Pandas data frame to have a better display.
crsp_tables = pd.DataFrame({'tables':crsp_tables}).sort_values('tables').reset_index(drop=True)  
crsp_tables.head(150)
# Out:
#                          tables
# 0                          acti
# 1                          asia
# 2                          asib
# 3                          asic
# 4                          asio
# 5                          asix
# 6                        bmdebt
# 7                      bmheader
# 8                      bmpaymts
# 9                      bmquotes
# 10                      bmyield
# 11                     bndprt06
# 12                     bndprt12
# 13                     bxcalind
# 14                     bxdlyind
# 15                     bxmthind
# 16                     bxquotes
# 17                      bxyield
# 18                          cap
# 19                   ccm_lookup
# 20                   ccm_qvards
# 21             ccmxpf_linktable
# 22               ccmxpf_lnkhist
# 23                ccmxpf_lnkrng
# 24               ccmxpf_lnkused
# 25                     comphead
# 26                     comphist
# 27                   compmaster
# 28                 contact_info
# 29                 crsp_cik_map
# 30              crsp_daily_data
# 31                  crsp_header
# 32            crsp_monthly_data
# 33                   crsp_names
# 34              crsp_portno_map
# 35       crsp_ziman_daily_index
# 36     crsp_ziman_monthly_index
# 37                       cs20yr
# 38                        cs5yr
# 39                        cs90d
# 40                     cst_hist
# 41                    daily_nav
# 42                daily_nav_ret
# 43                daily_returns
# 44                    dividends
# 45                       dport1
# 46                       dport2
# 47                       dport3
# 48                       dport4
# 49                       dport5
# 50                       dport6
# 51                       dport7
# 52                       dport8
# 53                       dport9
# 54                         dsbc
# 55                         dsbo
# 56                          dse
# 57                        dse62
# 58                  dse62delist
# 59                    dse62dist
# 60               dse62exchdates
# 61                   dse62names
# 62                  dse62nasdin
# 63                  dse62shares
# 64                       dseall
# 65                     dseall62
# 66                    dsedelist
# 67                      dsedist
# 68                 dseexchdates
# 69                     dsenames
# 70                    dsenasdin
# 71                    dseshares
# 72                          dsf
# 73                        dsf62
# 74                     dsf62_v2
# 75                       dsf_v2
# 76                       dsfhdr
# 77                     dsfhdr62
# 78                          dsi
# 79                        dsi62
# 80                         dsia
# 81                         dsib
# 82                         dsic
# 83                         dsio
# 84                         dsir
# 85                         dsix
# 86                         dsiy
# 87                       dsp500
# 88                    dsp500_v2
# 89                   dsp500list
# 90                dsp500list_v2
# 91                      dsp500p
# 92                         dssc
# 93                         dsso
# 94                      eod_cap
# 95                   eod_sector
# 96                       eod_vg
# 97                     erdport1
# 98                     erdport2
# 99                     erdport3
# 100                    erdport4
# 101                    erdport5
# 102                    erdport6
# 103                    erdport7
# 104                    erdport8
# 105                    erdport9
# 106                    ermport1
# 107                    ermport2
# 108                    ermport3
# 109                    ermport4
# 110                    ermport5
# 111                       fbpri
# 112                       fbyld
# 113                  front_load
# 114              front_load_det
# 115              front_load_grp
# 116                   fund_fees
# 117                  fund_flows
# 118                    fund_hdr
# 119               fund_hdr_hist
# 120                  fund_names
# 121                  fund_style
# 122                fund_summary
# 123               fund_summary2
# 124                    fwdask06
# 125                    fwdask12
# 126                    fwdave06
# 127                    fwdave12
# 128                    fwdbid06
# 129                    fwdbid12
# 130                    hldask06
# 131                    hldask12
# 132                    hldave06
# 133                    hldave12
# 134                    hldbid06
# 135                    hldbid12
# 136                    holdings
# 137            holdings_co_info
# 138            inddlyseriesdata
# 139          inddlyseriesdata62
# 140        inddlyseriesdata_ind
# 141          index_descriptions
# 142              index_type_map
# 143            indfamilyinfohdr
# 144          indfamilyinfohdr62
# 145        indfamilyinfohdr_ind
# 146  indissrebalancesummary_ind
# 147            indmthseriesdata
# 148          indmthseriesdata62
# 149        indmthseriesdata_ind

# %%
crsp_tables.shape
# Out:
# (380, 1)

# %% [markdown]
# We are going to focus on three tables:
#
# 1. MSF: Monthly Stock Files
# 2. MSE: Monthly Stock Events
# 3. MCTI: US Treasury and Inflation - Monthly
#
# Nice overview can be found [here](https://wrds-www.wharton.upenn.edu/pages/support/manuals-and-overviews/crsp/stocks-and-indices/overview-crsp-us-stock-database/).

# %% [markdown]
# ### Primary Keys (PK)
#
# * Company identifier: PERMCO
# * Security identifier: PERMNO
# * Date: monthly or daily

# %% [markdown]
# ## The Stock/Securities Files Table (msf or dsf)

# %% [markdown]
# ### All Variables in MSF

# %%
db.describe_table(library="crsp", table="msf")
# Out:
# Approximately 4531158 rows in crsp.msf.
#         name  nullable              type comment
# 0      cusip      True        VARCHAR(8)    None
# 1     permno      True  DOUBLE_PRECISION    None
# 2     permco      True  DOUBLE_PRECISION    None
# 3     issuno      True  DOUBLE_PRECISION    None
# 4      hexcd      True  DOUBLE_PRECISION    None
# 5     hsiccd      True  DOUBLE_PRECISION    None
# 6       date      True              DATE    None
# 7      bidlo      True  DOUBLE_PRECISION    None
# 8      askhi      True  DOUBLE_PRECISION    None
# 9        prc      True  DOUBLE_PRECISION    None
# 10       vol      True  DOUBLE_PRECISION    None
# 11       ret      True  DOUBLE_PRECISION    None
# 12       bid      True  DOUBLE_PRECISION    None
# 13       ask      True  DOUBLE_PRECISION    None
# 14    shrout      True  DOUBLE_PRECISION    None
# 15    cfacpr      True  DOUBLE_PRECISION    None
# 16   cfacshr      True  DOUBLE_PRECISION    None
# 17    altprc      True  DOUBLE_PRECISION    None
# 18    spread      True  DOUBLE_PRECISION    None
# 19  altprcdt      True              DATE    None
# 20      retx      True  DOUBLE_PRECISION    None

# %% [markdown]
# ### Extra Identifiers: names table

# %%
db.describe_table(library="crsp", table="stocknames")
# Out:
# Approximately 41054 rows in crsp.stocknames.
#          name  nullable              type comment
# 0      permno      True  DOUBLE_PRECISION    None
# 1      namedt      True              DATE    None
# 2   nameenddt      True              DATE    None
# 3       shrcd      True  DOUBLE_PRECISION    None
# 4      exchcd      True  DOUBLE_PRECISION    None
# 5       siccd      True  DOUBLE_PRECISION    None
# 6      ncusip      True        VARCHAR(8)    None
# 7      ticker      True        VARCHAR(8)    None
# 8      comnam      True       VARCHAR(35)    None
# 9      shrcls      True        VARCHAR(4)    None
# 10     permco      True  DOUBLE_PRECISION    None
# 11      hexcd      True  DOUBLE_PRECISION    None
# 12      cusip      True        VARCHAR(8)    None
# 13    st_date      True              DATE    None
# 14   end_date      True              DATE    None
# 15    namedum      True  DOUBLE_PRECISION    None

# %% [markdown]
# ### Which firm identifier to use?
#
# * PERMCO?
# * PERMNO?
# * CUSIP?
# * NCUSIP?
# * TICKER?

# %%
## An explample of name change
names_table = db.raw_sql('SELECT * FROM crsp.stocknames')

# %%
# Google
# names_table[names_table.permno==14542]
names_table[(names_table.ticker=='GOOG')| (names_table.ticker=='GOOGL')].sort_values('namedt')
# Out:
#         permno      namedt   nameenddt  shrcd  exchcd   siccd    ncusip  \
# 72446  90319.0  2004-08-19  2014-04-02   11.0     3.0  7375.0  38259P50
# 9510   14542.0  2014-04-03  2015-10-04   11.0     3.0  7375.0  38259P70
# 72447  90319.0  2014-04-03  2015-10-04   11.0     3.0  7375.0  38259P50
# 9511   14542.0  2015-10-05  2022-12-30   11.0     3.0  7375.0  02079K10
# 72448  90319.0  2015-10-05  2022-12-30   11.0     3.0  7375.0  02079K30
#
#       ticker        comnam shrcls   permco  hexcd     cusip     st_date  \
# 72446   GOOG    GOOGLE INC      A  45483.0    3.0  02079K30  2004-08-19
# 9510    GOOG    GOOGLE INC      C  45483.0    3.0  02079K10  2014-04-03
# 72447  GOOGL    GOOGLE INC      A  45483.0    3.0  02079K30  2004-08-19
# 9511    GOOG  ALPHABET INC      C  45483.0    3.0  02079K10  2014-04-03
# 72448  GOOGL  ALPHABET INC      A  45483.0    3.0  02079K30  2004-08-19
#
#          end_date  namedum
# 72446  2022-12-30      2.0
# 9510   2022-12-30      2.0
# 72447  2022-12-30      2.0
# 9511   2022-12-30      2.0
# 72448  2022-12-30      2.0

# %%
# HP
names_table[names_table.permno==32707]
# Out:
#         permno      namedt   nameenddt  shrcd  exchcd   siccd    ncusip  \
# 27333  32707.0  1962-07-02  1963-03-19   11.0     2.0  1311.0      None
# 27334  32707.0  1963-03-20  1968-01-01   11.0     1.0  1311.0      None
# 27335  32707.0  1968-01-02  2011-06-09   11.0     1.0  1311.0  42345210
# 27336  32707.0  2011-06-10  2022-12-30   11.0     1.0  1381.0  42345210
#
#       ticker                 comnam shrcls   permco  hexcd     cusip  \
# 27333     HP  HELMERICH & PAYNE INC   None  20902.0    1.0  42345210
# 27334     HP  HELMERICH & PAYNE INC   None  20902.0    1.0  42345210
# 27335     HP  HELMERICH & PAYNE INC   None  20902.0    1.0  42345210
# 27336     HP  HELMERICH & PAYNE INC   None  20902.0    1.0  42345210
#
#           st_date    end_date  namedum
# 27333  1962-07-02  2022-12-30      2.0
# 27334  1962-07-02  2022-12-30      2.0
# 27335  1962-07-02  2022-12-30      2.0
# 27336  1962-07-02  2022-12-30      2.0

# %%
# One permco, multiple permno, multiple cusip

# AT&T
names_table[names_table.permco==20103]
# Out:
#         permno      namedt   nameenddt  shrcd  exchcd   siccd    ncusip  \
# 1038   10401.0  1925-12-31  1962-07-01   11.0     1.0  4810.0      None
# 1039   10401.0  1962-07-02  1968-01-01   11.0     1.0  4811.0      None
# 1040   10401.0  1968-01-02  1994-04-20   11.0     1.0  4811.0  03017710
# 1041   10401.0  1994-04-21  2001-02-28   11.0     1.0  4812.0  00195710
# 1042   10401.0  2001-03-01  2002-11-18   11.0     1.0  4813.0  00195710
# 1043   10401.0  2002-11-19  2005-11-18   11.0     1.0  4813.0  00195750
# 66008  86746.0  1999-03-10  2001-02-28   11.0     1.0  4812.0  00195720
# 66009  86746.0  2001-03-01  2001-08-09   11.0     1.0  4813.0  00195720
# 66010  86747.0  1999-03-10  2001-02-28   11.0     1.0  4812.0  00195730
# 66011  86747.0  2001-03-01  2001-08-09   11.0     1.0  4813.0  00195730
# 68058  87831.0  2000-04-27  2001-02-28   11.0     1.0  4812.0  00195740
# 68059  87831.0  2001-03-01  2001-07-06   11.0     1.0  4813.0  00195740
#
#       ticker                         comnam shrcls   permco  hexcd     cusip  \
# 1038    None  AMERICAN TELEPHONE & TELEG CO   None  20103.0    1.0  00195750
# 1039       T  AMERICAN TELEPHONE & TELEG CO   None  20103.0    1.0  00195750
# 1040       T  AMERICAN TELEPHONE & TELEG CO   None  20103.0    1.0  00195750
# 1041       T                   A T & T CORP   None  20103.0    1.0  00195750
# 1042       T                   A T & T CORP   None  20103.0    1.0  00195750
# 1043       T                   A T & T CORP   None  20103.0    1.0  00195750
# 66008    LMG                   A T & T CORP      A  20103.0    1.0  00195720
# 66009    LMG                   A T & T CORP      A  20103.0    1.0  00195720
# 66010    LMG                   A T & T CORP      B  20103.0    1.0  00195730
# 66011    LMG                   A T & T CORP      B  20103.0    1.0  00195730
# 68058    AWE                   A T & T CORP   None  20103.0    1.0  00195740
# 68059    AWE                   A T & T CORP   None  20103.0    1.0  00195740
#
#           st_date    end_date  namedum
# 1038   1925-12-31  2005-11-18      2.0
# 1039   1925-12-31  2005-11-18      2.0
# 1040   1925-12-31  2005-11-18      2.0
# 1041   1925-12-31  2005-11-18      2.0
# 1042   1925-12-31  2005-11-18      2.0
# 1043   1925-12-31  2005-11-18      2.0
# 66008  1999-03-10  2001-08-09      2.0
# 66009  1999-03-10  2001-08-09      2.0
# 66010  1999-03-10  2001-08-09      2.0
# 66011  1999-03-10  2001-08-09      2.0
# 68058  2000-04-27  2001-07-06      2.0
# 68059  2000-04-27  2001-07-06      2.0

# %% [markdown]
# ### Difference between header information and historical information
#
# * Usually "h" in CRSP means header - a static characteristic. Either the most recent observation (hsiccd) or as the time the security was listed (hexcd).
# * Historical data: siccd, excd, etc.
# * Notice that for CUSIP it is different. Historical cusip is under NCUSIP.

# %% [markdown]
# ### Variables of interest
#
# 1. Identifiers: date, permno, permco
# 2. Price: prc
# 3. Return: ret
# 4. Return Ex-dividend: retx
# 5. Factor to adjust prices and shares outstading: 'cfacpr'/'cfacshr'
#
#
# Where to find variable definitions? [WRDS website](https://wrds-www.wharton.upenn.edu/documents/396/CRSP_US_Stock_Indices_Data_Descriptions.pdf).

# %%
sfvars = ['prc','vol','ret', 'retx','cfacpr','cfacshr']
query = """SELECT date, permno, permco, {} 
           FROM crsp.msf
           WHERE date>='1980-01-01'""".format(', '.join(sfvars))
print(query)
# Out:
# SELECT date, permno, permco, prc, vol, ret, retx, cfacpr, cfacshr
#            FROM crsp.msf
#            WHERE date>='1980-01-01'

# %%
msf_data = db.raw_sql(query, date_cols=['date'])
del(sfvars, query)

# %% [markdown]
# **Look at the data**

# %%
msf_data.head()
# Out:
#         date   permno  permco     prc     vol       ret      retx  cfacpr  \
# 0 1985-12-31  10000.0  7952.0     NaN     NaN       NaN       NaN     NaN
# 1 1986-01-31  10000.0  7952.0 -4.3750  1771.0       NaN       NaN     1.0
# 2 1986-02-28  10000.0  7952.0 -3.2500   828.0 -0.257143 -0.257143     1.0
# 3 1986-03-31  10000.0  7952.0 -4.4375  1078.0  0.365385  0.365385     1.0
# 4 1986-04-30  10000.0  7952.0 -4.0000   957.0 -0.098592 -0.098592     1.0
#
#    cfacshr
# 0      NaN
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0

# %%
# Check if we have a primary key
msf_data.duplicated(subset=['permno', 'date']).sum()
# Out:
# 0

# %%
msf_data.groupby(['permco', 'date']).permno.nunique().mean()
# Out:
# 1.09450846194898

# %%
msf_data.groupby(['permco', 'date']).permno.nunique().max()
# Out:
# 316

# %%
# Cumulative returns of Apple 
apple_ret = msf_data[msf_data.permno==14593].set_index(['date']).ret
((1+apple_ret).cumprod()).plot(title='Cumulative Returns of Apple')
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns of Apple'}, xlabel='date'>

# %%
# Cumulative returns of Apple 
apple_ret = msf_data[msf_data.permno==14593].set_index(['date']).ret
((1+apple_ret).cumprod()).plot(title='Cumulative Returns of Apple', logy=True)
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns of Apple'}, xlabel='date'>

# %% [markdown]
# ## The Stock/Security Events (mse, mseall, dse, dseall)

# %% [markdown]
# ### All variables in MSEALL

# %%
db.describe_table(library="crspq", table="mseall")
# Out:
# Approximately 1504243 rows in crspq.mseall.
#         name  nullable              type comment
# 0       date      True              DATE    None
# 1     comnam      True       VARCHAR(32)    None
# 2      cusip      True        VARCHAR(8)    None
# 3     dclrdt      True              DATE    None
# 4      dlamt      True  DOUBLE_PRECISION    None
# 5      dlpdt      True              DATE    None
# 6     dlstcd      True  DOUBLE_PRECISION    None
# 7     hsiccd      True  DOUBLE_PRECISION    None
# 8     issuno      True  DOUBLE_PRECISION    None
# 9     ncusip      True        VARCHAR(8)    None
# 10    nextdt      True              DATE    None
# 11     paydt      True              DATE    None
# 12    rcrddt      True              DATE    None
# 13    shrcls      True        VARCHAR(1)    None
# 14    shrflg      True  DOUBLE_PRECISION    None
# 15    ticker      True        VARCHAR(5)    None
# 16    permno      True  DOUBLE_PRECISION    None
# 17    permco      True  DOUBLE_PRECISION    None
# 18     hexcd      True  DOUBLE_PRECISION    None
# 19    hsicmg      True  DOUBLE_PRECISION    None
# 20    hsicig      True  DOUBLE_PRECISION    None
# 21  nameendt      True              DATE    None
# 22     shrcd      True  DOUBLE_PRECISION    None
# 23    exchcd      True  DOUBLE_PRECISION    None
# 24     siccd      True  DOUBLE_PRECISION    None
# 25   tsymbol      True       VARCHAR(10)    None
# 26     naics      True        VARCHAR(7)    None
# 27  primexch      True        VARCHAR(1)    None
# 28   trdstat      True        VARCHAR(1)    None
# 29   secstat      True        VARCHAR(1)    None
# 30    distcd      True  DOUBLE_PRECISION    None
# 31    divamt      True  DOUBLE_PRECISION    None
# 32     facpr      True  DOUBLE_PRECISION    None
# 33    facshr      True  DOUBLE_PRECISION    None
# 34    acperm      True  DOUBLE_PRECISION    None
# 35    accomp      True  DOUBLE_PRECISION    None
# 36    shrout      True  DOUBLE_PRECISION    None
# 37  shrenddt      True              DATE    None
# 38    nwperm      True  DOUBLE_PRECISION    None
# 39    nwcomp      True  DOUBLE_PRECISION    None
# 40    dlretx      True  DOUBLE_PRECISION    None
# 41     dlprc      True  DOUBLE_PRECISION    None
# 42     dlret      True  DOUBLE_PRECISION    None
# 43    trtscd      True  DOUBLE_PRECISION    None
# 44  trtsendt      True              DATE    None
# 45    nmsind      True  DOUBLE_PRECISION    None
# 46     mmcnt      True  DOUBLE_PRECISION    None
# 47    nsdinx      True  DOUBLE_PRECISION    None
# 48      year      True  DOUBLE_PRECISION    None
# 49     month      True  DOUBLE_PRECISION    None

# %% [markdown]
# ### Variables of Interest
# 1. Delisting returns: dlret, dlretx
# 2. Exchange codes: exchcd - 1 (NYSE), 2 (NYSE MKT), 3 (NASDAQ), 4 (Arca) or 5 (Bats).
# 3. Share Type Code: shrcd (usually we only look at Ordinary Common Shares, 10 and 11)
# 4. Industry classifications: siccd, naics
# 5. Stock Ticker

# %%
msevars = ['distcd','dlret', 'dlretx', 'exchcd','naics', 'ncusip', 'shrcd', 'shrout', 
           'siccd','comnam','ticker']
query = """SELECT date, permno, permco, {} 
           FROM crsp.mseall
           WHERE date>='1980-01-01'""".format(', '.join(msevars))
print(query)
# Out:
# SELECT date, permno, permco, distcd, dlret, dlretx, exchcd, naics, ncusip, shrcd, shrout, siccd, comnam, ticker
#            FROM crsp.mseall
#            WHERE date>='1980-01-01'

# %%
# Loot at columns you could download 
db.describe_table(library="crsp", table="mseall")
# Out:
# Approximately 3519543 rows in crsp.mseall.
#         name  nullable              type comment
# 0       date      True              DATE    None
# 1     comnam      True       VARCHAR(32)    None
# 2      cusip      True        VARCHAR(8)    None
# 3     dclrdt      True              DATE    None
# 4      dlamt      True  DOUBLE_PRECISION    None
# 5      dlpdt      True              DATE    None
# 6     dlstcd      True  DOUBLE_PRECISION    None
# 7     hsiccd      True  DOUBLE_PRECISION    None
# 8     issuno      True  DOUBLE_PRECISION    None
# 9     ncusip      True        VARCHAR(8)    None
# 10    nextdt      True              DATE    None
# 11     paydt      True              DATE    None
# 12    rcrddt      True              DATE    None
# 13    shrcls      True        VARCHAR(1)    None
# 14    shrflg      True  DOUBLE_PRECISION    None
# 15    ticker      True        VARCHAR(5)    None
# 16    permno      True  DOUBLE_PRECISION    None
# 17    permco      True  DOUBLE_PRECISION    None
# 18     hexcd      True  DOUBLE_PRECISION    None
# 19    hsicmg      True  DOUBLE_PRECISION    None
# 20    hsicig      True  DOUBLE_PRECISION    None
# 21  nameendt      True              DATE    None
# 22     shrcd      True  DOUBLE_PRECISION    None
# 23    exchcd      True  DOUBLE_PRECISION    None
# 24     siccd      True  DOUBLE_PRECISION    None
# 25   tsymbol      True       VARCHAR(10)    None
# 26     naics      True        VARCHAR(7)    None
# 27  primexch      True        VARCHAR(1)    None
# 28   trdstat      True        VARCHAR(1)    None
# 29   secstat      True        VARCHAR(1)    None
# 30    distcd      True  DOUBLE_PRECISION    None
# 31    divamt      True  DOUBLE_PRECISION    None
# 32     facpr      True  DOUBLE_PRECISION    None
# 33    facshr      True  DOUBLE_PRECISION    None
# 34    acperm      True  DOUBLE_PRECISION    None
# 35    accomp      True  DOUBLE_PRECISION    None
# 36    shrout      True  DOUBLE_PRECISION    None
# 37  shrenddt      True              DATE    None
# 38    nwperm      True  DOUBLE_PRECISION    None
# 39    nwcomp      True  DOUBLE_PRECISION    None
# 40    dlretx      True  DOUBLE_PRECISION    None
# 41     dlprc      True  DOUBLE_PRECISION    None
# 42     dlret      True  DOUBLE_PRECISION    None
# 43    trtscd      True  DOUBLE_PRECISION    None
# 44  trtsendt      True              DATE    None
# 45    nmsind      True  DOUBLE_PRECISION    None
# 46     mmcnt      True  DOUBLE_PRECISION    None
# 47    nsdinx      True  DOUBLE_PRECISION    None
# 48      year      True  DOUBLE_PRECISION    None
# 49     month      True  DOUBLE_PRECISION    None

# %%
mse_data = db.raw_sql(query, date_cols=['date'])
del(msevars, query)

# %% [markdown]
# **Look at the data...**

# %%
mse_data[mse_data.permno==14593]
# Out:
#              date   permno  permco  distcd  dlret  dlretx  exchcd   naics  \
# 383320 1980-12-31  14593.0     7.0     NaN    NaN     NaN     3.0    None
# 383321 1981-06-30  14593.0     7.0     NaN    NaN     NaN     3.0    None
# 383322 1981-09-30  14593.0     7.0     NaN    NaN     NaN     3.0    None
# 383323 1981-12-31  14593.0     7.0     NaN    NaN     NaN     3.0    None
# 383324 1982-03-31  14593.0     7.0     NaN    NaN     NaN     3.0    None
# ...           ...      ...     ...     ...    ...     ...     ...     ...
# 383802 2022-08-31  14593.0     7.0  1232.0    NaN     NaN     3.0  334220
# 383803 2022-09-30  14593.0     7.0     NaN    NaN     NaN     3.0  334220
# 383804 2022-10-31  14593.0     7.0     NaN    NaN     NaN     3.0  334220
# 383805 2022-11-30  14593.0     7.0  1232.0    NaN     NaN     3.0  334220
# 383806 2022-12-30  14593.0     7.0     NaN    NaN     NaN     3.0  334220
#
#           ncusip  shrcd      shrout   siccd              comnam ticker
# 383320  03783310   11.0     55136.0  3573.0  APPLE COMPUTER INC   AAPL
# 383321  03783310   11.0     55136.0  3573.0  APPLE COMPUTER INC   AAPL
# 383322  03783310   11.0     55309.0  3573.0  APPLE COMPUTER INC   AAPL
# 383323  03783310   11.0     55421.0  3573.0  APPLE COMPUTER INC   AAPL
# 383324  03783310   11.0     56488.0  3573.0  APPLE COMPUTER INC   AAPL
# ...          ...    ...         ...     ...                 ...    ...
# 383802  03783310   11.0  16070752.0  3571.0           APPLE INC   AAPL
# 383803  03783310   11.0  15943425.0  3571.0           APPLE INC   AAPL
# 383804  03783310   11.0  15908118.0  3571.0           APPLE INC   AAPL
# 383805  03783310   11.0  15908118.0  3571.0           APPLE INC   AAPL
# 383806  03783310   11.0  15908118.0  3571.0           APPLE INC   AAPL
#
# [487 rows x 14 columns]

# %% [markdown]
# ### Check Primary Key

# %%
# Check PK
mse_data.duplicated(subset=['date','permno']).sum()
# Out:
# 35322

# %%
# Check Duplicates
mse_data[mse_data.duplicated(subset=['date','permno'])]
# Out:
#              date   permno   permco  distcd  dlret  dlretx  exchcd   naics  \
# 59     1994-06-30  10001.0   7953.0  5523.0    NaN     NaN     3.0    None
# 197    2008-02-29  10001.0   7953.0  1222.0    NaN     NaN     3.0  221210
# 351    1993-12-31  10002.0   7954.0  1272.0    NaN     NaN     3.0    None
# 1811   1986-12-31  10020.0   7972.0  1212.0    NaN     NaN     3.0    None
# 1830   1988-12-30  10020.0   7972.0  1232.0    NaN     NaN     3.0    None
# ...           ...      ...      ...     ...    ...     ...     ...     ...
# 179346 2010-12-31  93413.0  51187.0  1272.0    NaN     NaN     4.0  525990
# 179347 2010-12-31  93413.0  51187.0  2216.0    NaN     NaN     4.0  525990
# 179764 2010-12-31  93417.0  53120.0  2216.0    NaN     NaN     4.0  525990
# 180329 2020-12-31  93421.0  52902.0  2216.0    NaN     NaN     4.0  525990
# 180342 2021-12-31  93421.0  52902.0  2216.0    NaN     NaN     4.0  525990
#
#           ncusip  shrcd   shrout   siccd                            comnam  \
# 59      29274A10   11.0   2191.0  4920.0                   ENERGY WEST INC
# 197     29274A20   11.0   4345.0  4920.0                   ENERGY WEST INC
# 351     83623410   11.0   2999.0  6710.0  SOUTH ALABAMA BANCORPORATION INC
# 1811    49307510   11.0   5800.0  6710.0          KEY CENTURION BANCSHARES
# 1830    49307510   11.0  20281.0  6710.0          KEY CENTURION BANCSHARES
# ...          ...    ...      ...     ...                               ...
# 179346  18383M88   73.0   1100.0  6726.0              CLAYMORE E T F TRUST
# 179347  18383M88   73.0   1100.0  6726.0              CLAYMORE E T F TRUST
# 179764  37950E78   73.0   1800.0  6726.0                    GLOBAL X FUNDS
# 180329  46138E63   73.0   4450.0  6726.0            INVESCO E T F TRUST II
# 180342  46138E63   73.0   5650.0  6726.0            INVESCO E T F TRUST II
#
#        ticker
# 59       EWST
# 197      EWST
# 351      SABC
# 1811     KEYC
# 1830     KEYC
# ...       ...
# 179346   BSCB
# 179347   BSCB
# 179764   BRAZ
# 180329   PICB
# 180342   PICB
#
# [35322 rows x 14 columns]

# %%
mse_data[(mse_data.permno==10001)&(mse_data.date=='2008-02-29')]
# Out:
# 133925            RICHARDSON MERRELL INC    RXM
# 192487            IPALCO ENTERPRISES INC    IPL
# 244541              BAV LIQUIDATING CORP    BAT
# 244542              BAV LIQUIDATING CORP    BAT
# 244543              BAV LIQUIDATING CORP    BAT
# 244544              BAV LIQUIDATING CORP    BAT
# 244545              BAV LIQUIDATING CORP    BAT
# 244546              BAV LIQUIDATING CORP    BAT
# 244549              BAV LIQUIDATING CORP    BAT
# 269225                      ENSERCH CORP    ENS
# 287516           SMITHKLINE BECKMAN CORP    SKB
# 287517           SMITHKLINE BECKMAN CORP    SKB
# 287519           SMITHKLINE BECKMAN CORP    SKB
# 290118                       TENNECO INC    TEN
# 297281    BLOCKBUSTER ENTERTAINMENT CORP     BV
# 298042     AMERICAN HOSPITAL SUPPLY CORP    AHS
# 362169      PARAMOUNT COMMUNICATIONS INC    PCI
# 362170      PARAMOUNT COMMUNICATIONS INC    PCI
# 362171      PARAMOUNT COMMUNICATIONS INC    PCI
# 391834   FIRST AMERICAN BK PALM BEACH FL   FIAM
# 428080         WARNER COMMUNICATIONS INC    WCI
# 451644           PREMIER INDUSTRIAL CORP    PRE
# 20733          ANIXTER INTERNATIONAL INC    AXE
# 50332                BEVERLY ENTERPRISES    BEV
# 56379              GROSS TELECASTING INC    GGG
# 62317              F R LIQUIDATING GROUP     FR
# 62318              F R LIQUIDATING GROUP     FR
# 62319              F R LIQUIDATING GROUP     FR
# 62320              F R LIQUIDATING GROUP     FR
# 68470                  LIBERTY HOMES INC   LIBH
# 82742              HIGHLAND CAPITAL CORP    HLD
# 82743              HIGHLAND CAPITAL CORP    HLD
# 82744              HIGHLAND CAPITAL CORP    HLD
# 109868                   COOPER LABS INC    COO
# 109869                   COOPER LABS INC    COO
# 210683         OHIO CITIZENS BANCORP INC   OCEY
# 236061                        S F M CORP    SFM
# 240709              PANEX INDUSTRIES INC   PANX
# 276360           PIEDMONT MANAGEMENT INC   PMAN
# 280407                       HEIZER CORP    HZR
# 289003           UNITED CABLE TELEVISION    UCT
# 311758                      QUANTUM CORP   QNTM
# 321711              CITADEL HOLDING CORP    CDL
# 343975            AMERICAN FRUCTOSE CORP    AFC
# 375499        HERITAGE ENTERTAINMENT INC    HHH
# 426573             CALATLANTIC GROUP INC    CAA
# 435120              SUPER RITE FOODS INC   SRFI
# 491315    VAN KAMPEN MUNICIPAL INCOME TR    VMT
# 491316    VAN KAMPEN MUNICIPAL INCOME TR    VMT
# 8946               GENERAL SCIENCES CORP   GSCX
# 53918                HENLEY GROUP INC DE   HENG
# 53919                HENLEY GROUP INC DE   HENG
# 67235                 SIX CONTINENTS PLC    SXC
# 76204                        SAFEWAY INC    SWY
# 109221   NUVEEN NEW YORK INV QTY MUNI FD    NQN
# 115562  HEALTH MANAGEMENT ASSOCIATES INC    HMA
# 118540                      TAKECARE INC   TKCR
# 126228  NUVEEN NY SELECT QUALITY MUNI FD    NVN
# 131285                      CHEROKEE INC   CHKE
# 131286                      CHEROKEE INC   CHKE
# 146784   BLACKROCK MUNI TARGET TM TR INC    BMN
# 175414    BALLY GAMING INTERNATIONAL INC   BGII
# 179413  NUVEEN NY QLTY INCOME MUN FD INC    NUN
# 180382     VAN KAMPEN PA QUALITY MUNI TR    VPQ
# 180740    VAN KAMPEN CAP FL QLTY MUNI TR    VFM
# 180920     VAN KAMPEN NY QUALITY MUNI TR    VNM
# 183064  NUVEEN PREMIER MUNI OPPTY FD INC    NIF
# 201397  BLACKROCK INSURED MUNI TM TR INC    BMT
# 210095      ADVANCED MACHINE VISION CORP   AMVC
# 221075                      EL PASO CORP     EP
# 230322       DELAWARE INVTS MINN MUN INC    VMN
# 234120  VAN KAMPEN TRUST INV GR FL MUNIS    VTF
# 278066   VAN KAMPEN ADVAN PA MUNI INC TR    VAP
# 280557       NUVEEN SELECT MATS MUN FD 2    NIR
# 309133      UNITED ARTISTS COMMUNICS INC   UACI
# 331387    NUVEEN NY PREM INC MUNI FD INC    NNF
# 360115  NUVEEN INSURED CA PR INC MN FD 2    NCL
# 369758      BROOKFIELD PROPERTY REIT INC   BPYU
# 389502          UNITED STATES TRUST CORP   USTC
# 398640   VAN KAMPEN NY VALUE MUNI INC TR    VNV
# 408344   NUVEEM PREM INC MUNI OPPTY FUND    NPX
# 416321                    PRICE REIT INC    RET
# 430030         SPHERE DRAKE HOLDINGS LTD     SD
# 443118  DELAWARE INVTS MINN MUNI INC III    VYM
# 444057        CHELSEA PROPERTY GROUP INC    CPG
# 477313            FLETCHER CHALLENGE LTD    FLC
# 477314            FLETCHER CHALLENGE LTD    FLC
# 78693               ASSOCIATED GROUP INC  AGRPA
# 78746               ASSOCIATED GROUP INC  AGRPB
# 127275               D L B OIL & GAS INC   DLBI
# 127278               D L B OIL & GAS INC   DLBI
# 147424                      U S WEST INC    UMG
# 158609                 CARDIOMETRICS INC   CFLO
# 187942             WILEY JOHN & SONS INC   WILL
# 247293          CANADIAN PACIFIC LTD NEW     CP
# 247294          CANADIAN PACIFIC LTD NEW     CP
# 247295          CANADIAN PACIFIC LTD NEW     CP
# 247296          CANADIAN PACIFIC LTD NEW     CP
# 249081              ACACIA RESEARCH CORP   ACRI
# 266113         ALGOS PHARMACEUTICAL CORP   ALGO
# 286611           PRECISION DRILLING CORP    PDS
# 328730         CABLE & WIRELESS COMM PLC    CWZ
# 338174         GREATER COMMUNITY BANCORP   GFLS
# 358534   COMPANHIA PARANAENSE DE ENERGIA    ELP
# 490408  EATON VANCE NATIONAL MUNI INC TR    FEV
# 18064               REDBACK NETWORKS INC   RBAK
# 119638        REGIONAL BANK HOLDRS TRUST    RKH
# 119639        REGIONAL BANK HOLDRS TRUST    RKH
# 119640        REGIONAL BANK HOLDRS TRUST    RKH
# 120711            UTILITIES HOLDRS TRUST    UTH
# 120712            UTILITIES HOLDRS TRUST    UTH
# 120713            UTILITIES HOLDRS TRUST    UTH
# 120714            UTILITIES HOLDRS TRUST    UTH
# 140195             MARKET 2000 HOLDRS TR    MKH
# 140196             MARKET 2000 HOLDRS TR    MKH
# 140197             MARKET 2000 HOLDRS TR    MKH
# 140198             MARKET 2000 HOLDRS TR    MKH
# 140199             MARKET 2000 HOLDRS TR    MKH
# 140200             MARKET 2000 HOLDRS TR    MKH
# 140201             MARKET 2000 HOLDRS TR    MKH
# 140202             MARKET 2000 HOLDRS TR    MKH
# 140203             MARKET 2000 HOLDRS TR    MKH
# 140204             MARKET 2000 HOLDRS TR    MKH
# 140205             MARKET 2000 HOLDRS TR    MKH
# 140206             MARKET 2000 HOLDRS TR    MKH
# 165661            TELEFONICA MOVILES S A    TEM
# 166026            WIRELESS HOLDERS TRUST    WMH
# 166027            WIRELESS HOLDERS TRUST    WMH
# 166028            WIRELESS HOLDERS TRUST    WMH
# 173287   CELLULAR COMMUNICATIONS INC NEW  COMMA
# 175227          OIL SERVICE HOLDRS TRUST    OIH
# 186647               RETAIL HOLDRS TRUST    RTH
# 186649               RETAIL HOLDRS TRUST    RTH
# 186650               RETAIL HOLDRS TRUST    RTH
# 200508            LIBERTY MEDIA CORP NEW      L
# 200567            LIBERTY MEDIA CORP NEW    LMC
# 202554                        C P HOLDRS    HCH
# 206200        BLACKROCK MUN 2018 TERM TR    BPK
# 206417     BLACKROCK NY MUN 2018 TERM TR    BLH
# 206628  BLACKROCK CALIF MUN 2018 TERM TR    BJZ
# 225471     NUVEEN NY DIV ADV MUNI INC FD    NKO
# 232800                        ALTANA A G    AAA
# 244393              TELECOM HOLDRS TRUST    TTH
# 244394              TELECOM HOLDRS TRUST    TTH
# 244395              TELECOM HOLDRS TRUST    TTH
# 244397              TELECOM HOLDRS TRUST    TTH
# 258765                 E T F ADVISORS TR    TFT
# 258767                 E T F ADVISORS TR    TFT
# 263099             PENNANT RESOURCES LTD  PENRF
# 267293                  VIRGIN MEDIA INC   VMED
# 328180                LUMINA COPPER CORP    LCC
# 384778                      XENOGEN CORP   XGEN
# 401278    FIRST TR STRATEGIC HIGH INC FD    FHI
# 25367    FIRST TRUST STRAT HI INC FD III    FHO
# 74104                  SPDR SERIES TRUST    INY
# 74228                  SPDR SERIES TRUST    CXA
# 75947         ABRAXIS BIOSCIENCE INC NEW   ABII
# 78254   NUVEEN MUNICIPAL HI INC OPP FD 2    NMD
# 177775                 SPDR SERIES TRUST   BABS

# %% [markdown]
# ### DISTCD causes duplicates
# * DISTCD: event code that records list of events describing cash dividends, capital adjustments, and other distributions made to shareholders of a security;
# * For stock/date there might be multiple events.
# * For example, in the case of Energy West (EWST)
#     * 1222: US cash dividend, monthly, taxable same rate as dividends
#     * 5523: Stock split, non-taxable

# %%
# Redownlod without distcd 
msevars = ['comnam', 'dlret', 'dlretx', 'exchcd','naics', 'cusip', 'ncusip', 'shrcd', 'shrout', 
           'siccd','ticker']
query = """SELECT date, permno, permco, {} 
           FROM crspq.mseall
           WHERE date>='1980-01-01'""".format(', '.join(msevars))
print(query)
# Out:
# SELECT date, permno, permco, comnam, dlret, dlretx, exchcd, naics, cusip, ncusip, shrcd, shrout, siccd, ticker
#            FROM crspq.mseall
#            WHERE date>='1980-01-01'

# %%
mse_data = db.raw_sql(query, date_cols=['date'])
del(msevars, query)

# %%
mse_data = mse_data[~mse_data.duplicated()].copy()

# %%
# Check PK
mse_data.duplicated(subset=['date','permno']).sum()
# Out:
# 0

# %%
mse_data.head()
# Out:
#         date   permno  permco                     comnam  dlret  dlretx  \
# 0 1986-01-31  10000.0  7952.0  OPTIMUM MANUFACTURING INC    NaN     NaN
# 1 1986-03-31  10000.0  7952.0  OPTIMUM MANUFACTURING INC    NaN     NaN
# 2 1986-04-30  10000.0  7952.0  OPTIMUM MANUFACTURING INC    NaN     NaN
# 3 1986-05-30  10000.0  7952.0  OPTIMUM MANUFACTURING INC    NaN     NaN
# 4 1986-06-30  10000.0  7952.0  OPTIMUM MANUFACTURING INC    NaN     NaN
#
#    exchcd naics     cusip    ncusip  shrcd  shrout   siccd ticker
# 0     3.0  None  68391610  68391610   10.0  3680.0  3990.0  OMFGA
# 1     3.0  None  68391610  68391610   10.0  3680.0  3990.0  OMFGA
# 2     3.0  None  68391610  68391610   10.0  3793.0  3990.0  OMFGA
# 3     3.0  None  68391610  68391610   10.0  3793.0  3990.0  OMFGA
# 4     3.0  None  68391610  68391610   10.0  3793.0  3990.0  OMFGA

# %% [markdown]
# ## Merge MSF and MSEALL

# %% [markdown]
# When merging mse and msf tables we should copy information from event observations to succeeding non-event observations.

# %% [markdown]
# Check data types: for some reason the merge does not work for PERMNO as float

# %%
msf_data.dtypes
# Out:
# date       datetime64[ns]
# permno            float64
# permco            float64
# prc               float64
# vol               float64
# ret               float64
# retx              float64
# cfacpr            float64
# cfacshr           float64
# dtype: object

# %%
## Check data types
mse_data.dtypes
# Out:
# date      datetime64[ns]
# permno           float64
# permco           float64
# comnam            object
# dlret            float64
# dlretx           float64
# exchcd           float64
# naics             object
# cusip             object
# ncusip            object
# shrcd            float64
# shrout           float64
# siccd            float64
# ticker            object
# dtype: object

# %%
# Change Permno Data Type.
msf_data['permno'] = msf_data['permno'].astype('int')
mse_data['permno'] = mse_data['permno'].astype('int')

# %%
msf_data.sort_values(['date', 'permno'], inplace=True)
mse_data.sort_values(['date', 'permno'], inplace=True)

# %% [markdown]
# **Merge tables with following logic:**
# * For each msf observation, merge most recent mseall observation with same permno,
# * If particular permno-date combination does not exist in msf but does in mseall, do not include that observation.
#
# **How to do this?** Pandas is powerful!

# %%
from IPython.display import IFrame
IFrame('https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge_asof.html', width=900, height=400)
# Out:
#         <iframe
#             width="900"
#             height="400"
#             src="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge_asof.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Check of coverage
x = pd.Series(msf_data.permno.unique())
y = pd.Series(mse_data.permno.unique())

# %%
# Have price but no event?
x[~x.isin(y)][:20]
# Out:
# Series([], dtype: int64)

# %%
# Have event but no price?
y[~y.isin(x)][:20]
# Out:
# 306     30921
# 315     31544
# 359     34893
# 770     55723
# 1006    68778
# 1021    71432
# 1930    50391
# 2868    40344
# 3111    51844
# 3578    31820
# 3618    43756
# 3640    48362
# 3654    51319
# 3796    30251
# 4421    33435
# 4512    14860
# 4565    33996
# 4566    34797
# 4676    69834
# 4756    45196
# dtype: int64

# %%
# Check if delisting happens only once per security
mse_data[mse_data.dlret.notnull()].groupby(['permno']).date.value_counts().max()
# Out:
# 1

# %%
# Check if delisting returns only appears after the firm is not longer covered by msf
test = mse_data[mse_data.dlret.notnull()]
test = pd.merge(msf_data, test[['permno', 'dlret', 'date']], on=['permno'])
test[test.date_x>test.date_y]
# Out:
# Empty DataFrame
# Columns: [date_x, permno, permco, prc, vol, ret, retx, cfacpr, cfacshr, dlret, date_y]
# Index: []

# %%
crsp = pd.merge_asof(msf_data, 
                     mse_data, 
                     on='date', 
                     by=['permno','permco'], 
                     direction='backward')

# %%
crsp.columns
# Out:
# Index(['date', 'permno', 'permco', 'prc', 'vol', 'ret', 'retx', 'cfacpr',
#        'cfacshr', 'comnam', 'dlret', 'dlretx', 'exchcd', 'naics', 'cusip',
#        'ncusip', 'shrcd', 'shrout', 'siccd', 'ticker'],
#       dtype='object')

# %%
crsp[crsp.ticker=='GOOG'].head()
# Out:
#               date  permno   permco         prc        vol       ret  \
# 2171823 2004-08-31   90319  45483.0  102.370003   669547.0       NaN
# 2178734 2004-09-30   90319  45483.0  129.600006  1066083.0  0.265996
# 2185668 2004-10-29   90319  45483.0  190.639999  2580994.0  0.470988
# 2192604 2004-11-30   90319  45483.0  181.979996  2788008.0 -0.045426
# 2199551 2004-12-31   90319  45483.0  192.789993  1457027.0  0.059402
#
#              retx  cfacpr  cfacshr      comnam  dlret  dlretx  exchcd   naics  \
# 2171823       NaN  39.938     20.0  GOOGLE INC    NaN     NaN     3.0  514191
# 2178734  0.265996  39.938     20.0  GOOGLE INC    NaN     NaN     3.0  514191
# 2185668  0.470988  39.938     20.0  GOOGLE INC    NaN     NaN     3.0  514191
# 2192604 -0.045426  39.938     20.0  GOOGLE INC    NaN     NaN     3.0  514191
# 2199551  0.059402  39.938     20.0  GOOGLE INC    NaN     NaN     3.0  514191
#
#             cusip    ncusip  shrcd   shrout   siccd ticker
# 2171823  02079K30  38259P50   11.0  33603.0  7375.0   GOOG
# 2178734  02079K30  38259P50   11.0  57857.0  7375.0   GOOG
# 2185668  02079K30  38259P50   11.0  57857.0  7375.0   GOOG
# 2192604  02079K30  38259P50   11.0  57857.0  7375.0   GOOG
# 2199551  02079K30  38259P50   11.0  95542.0  7375.0   GOOG

# %%
# Check Primary Key
crsp.duplicated(subset=['permno','date']).sum()
# Out:
# 0

# %%
# Check Apple
crsp[crsp.permno==14593].tail()
# Out:
#               date  permno  permco         prc         vol       ret  \
# 3748813 2022-08-31   14593     7.0  157.220001  15086319.0 -0.031137
# 3758503 2022-09-30   14593     7.0  138.199997  20853206.0 -0.120977
# 3768194 2022-10-31   14593     7.0  153.339996  18666227.0  0.109551
# 3777890 2022-11-30   14593     7.0  148.029999  17240790.0 -0.033129
# 3787565 2022-12-30   14593     7.0  129.929993  16746278.0 -0.122273
#
#              retx  cfacpr  cfacshr     comnam  dlret  dlretx  exchcd   naics  \
# 3748813 -0.032552     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220
# 3758503 -0.120977     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220
# 3768194  0.109551     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220
# 3777890 -0.034629     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220
# 3787565 -0.122273     1.0      1.0  APPLE INC    NaN     NaN     3.0  334220
#
#             cusip    ncusip  shrcd      shrout   siccd ticker
# 3748813  03783310  03783310   11.0  16070752.0  3571.0   AAPL
# 3758503  03783310  03783310   11.0  15943425.0  3571.0   AAPL
# 3768194  03783310  03783310   11.0  15908118.0  3571.0   AAPL
# 3777890  03783310  03783310   11.0  15908118.0  3571.0   AAPL
# 3787565  03783310  03783310   11.0  15908118.0  3571.0   AAPL

# %% [markdown]
# ## Calculate Variables of Interest

# %% [markdown]
# ### Adjusted Returns
#
# Add to the ret series the delisting returns

# %%
# Returns adjusted for delisting
crsp['retadj'] = ((1+crsp['ret'].fillna(0))*(1+crsp['dlret'].fillna(0))-1)
crsp.loc[crsp[['ret', 'dlret']].isnull().all(axis=1), 'retadj'] = np.nan

# %% [markdown]
# ### Market Equity Value

# %% [markdown]
# #### Can prices be negative?

# %%
(crsp.prc<0).mean()
# Out:
# 0.1314447620424935

# %%
(crsp.prc==0).mean()
# Out:
# 0.0

# %% [markdown]
# **Why Negative Prices?**<BR><BR>
#
# * If the closing price is not available for any given period, the number in the price field is replaced with a bid/ask average.
# * Bid/ask averages have dashes placed in front of them.
# * These do not incorrectly reflect negative prices; they serve to distinguish bid/ask averages from actual closing prices. If neither the price nor bid/ask average is available, the field is set to N/A.

# %% [markdown]
# #### Can number of shares outstanding be negative?

# %%
(crsp.shrout<0).sum()
# Out:
# 0

# %% [markdown]
# #### Create Market Equity (ME)

# %%
# SHROUT is the number of publicly held shares, recorded in thousands. ME will be reported in 1,000,000 ($10^6$),
# Like on Ken French's website. 
crsp['me'] = abs(crsp['prc']) * (crsp['shrout']/1000)

# %%
# Also, some companies have multiple shareclasses (=PERMNOs).
# To get the company ME, we need to calculate the sum of ME over all shareclasses for one company (=PERMCO).
# This is used for sorting, but not for weights.

# Create MEsum
crsp['mesum'] = crsp.groupby(['date', 'permco']).me.transform(np.sum, min_count=1)

# %%
# If the stock is delisted, we set ME to NaN.
crsp.loc[crsp.dlret.notnull(), 'me'] = np.nan
crsp.loc[crsp.dlret.notnull(), 'mesum'] = np.nan

# %% [markdown]
# #### Adjusting for Stock Splits and Other Corporate Actions
#
# * Returns are already adjusted for splits, but prices and shares outstanding are not.
# * To adjust prices and shares outstanding, use the following use:
#     * Adjusted prices = PRC / CFACPR
#     * Adjusted shares = SHROUT * CFACSHR

# %% [markdown]
# ### ME Lag
#
# MElag is used as portfolio weights any value weighted portfolio (eg. in the FF factors).

# %%
crsp.sort_values(['permno','date'], inplace=True)

# %%
crsp['melag_nt']=crsp.groupby(['permno']).me.shift(1)

# %%
# What to do if ME is missing?
crsp['melag'] = crsp.groupby('permno').melag_nt.fillna(method='pad')

# Fill na after delisting
#df = post_event_nan(df=df, event=df.lag_dlret.notnull(), vars=['melag'], id_vars=['permno', 'edate'])

# %% [markdown]
# ### Rankyear

# %%
# Portfolios are rebalanced in the end of june
crsp['rankyear'] = crsp.date.dt.year
crsp.loc[crsp.date.dt.month <= 6, 'rankyear'] = crsp.loc[crsp.date.dt.month <= 6, 'rankyear'] - 1

# %% [markdown]
# ## Add Risk Free

# %%
# Dowload the data
#%% Import Data
query = "SELECT caldt as date, t30ret as rf FROM crspq.mcti"
rf = db.raw_sql(query, date_cols=['date'])

# %%
rf.head()
# Out:
#         date        rf
# 0 1925-12-31       NaN
# 1 1926-01-30  0.002951
# 2 1926-02-27  0.002768
# 3 1926-03-31  0.002778
# 4 1926-04-30  0.003072

# %%
# Month dates: dates do not match directly to the ones in CRSP
rf['mdate'] = rf.date.dt.year*100+rf.date.dt.month

# %%
rf.drop(columns=['date'], inplace=True)

# %%
crsp['mdate']=crsp.date.dt.year*100+crsp.date.dt.month

# %%
crsp = pd.merge(crsp, rf, on=['mdate'])

# %%
crsp.rf.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Save Output

# %%
crsp.head()
# Out:
#         date  permno  permco  prc  vol  ret  retx  cfacpr  cfacshr comnam  \
# 0 1985-12-31   10000  7952.0  NaN  NaN  NaN   NaN     NaN      NaN    NaN
# 1 1985-12-31   10001  7953.0  NaN  NaN  NaN   NaN     NaN      NaN    NaN
# 2 1985-12-31   10002  7954.0  NaN  NaN  NaN   NaN     NaN      NaN    NaN
# 3 1985-12-31   10003  7957.0  NaN  NaN  NaN   NaN     NaN      NaN    NaN
# 4 1985-12-31   10005  7961.0  NaN  NaN  NaN   NaN     NaN      NaN    NaN
#
#    ...  siccd  ticker  retadj  me mesum melag_nt  melag  rankyear   mdate  \
# 0  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
# 1  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
# 2  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
# 3  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
# 4  ...    NaN     NaN     NaN NaN   NaN      NaN    NaN      1985  198512
#
#          rf
# 0  0.006139
# 1  0.006139
# 2  0.006139
# 3  0.006139
# 4  0.006139
#
# [5 rows x 28 columns]

# %%
crsp.columns
# Out:
# Index(['date', 'permno', 'permco', 'prc', 'vol', 'ret', 'retx', 'cfacpr',
#        'cfacshr', 'comnam', 'dlret', 'dlretx', 'exchcd', 'naics', 'cusip',
#        'ncusip', 'shrcd', 'shrout', 'siccd', 'ticker', 'retadj', 'me', 'mesum',
#        'melag_nt', 'melag', 'rankyear', 'mdate', 'rf'],
#       dtype='object')

# %%
# Make sure to change the path here for the place you want to save the data in your computer. 
crsp.to_pickle(path='./crsp_monthly.pkl')
